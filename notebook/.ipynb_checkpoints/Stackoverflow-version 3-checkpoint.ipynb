# %%
#import des librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data cleanning

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ray63\\Documents\\Pythontest'

# %%
csv_path ='C:\\Users\\ray63\\Documents\\Pythontest\\data'

# %%
data = pd.read_csv(os.path.join(csv_path, 'QueryResults.csv'))

# %%
data.head()
# Out:
#                                                Title  \
# 0  Import CSV file to strongly typed data structu...
# 1               Change hash without reload in jQuery
# 2                Pass by reference or pass by value?
# 3   What are MVP and MVC and what is the difference?
# 4                       LINQ on the .NET 2.0 Runtime
#
#                                                 Body  \
# 0  <p>What's the best way to import a CSV file in...
# 1  <p>I have the following code:</p>\n\n<pre><cod...
# 2  <p>When learning a new programming language, o...
# 3  <p>When looking beyond the <a href="https://en...
# 4  <p>Can a LINQ enabled app run on a machine tha...
#
#                                                 Tags       Id  Score  \
# 0                    <c#><vb.net><file><csv><import>     1898    109
# 1  <jquery><hash><reload><fragment-identifier><wi...  1939041     56
# 2  <language-agnostic><oop><parameters><pass-by-r...     2027     52
# 3  <user-interface><model-view-controller><design...     2056   2319
# 4              <.net><linq><.net-3.5><.net-2.0><clr>     2138     61
#
#    ViewCount  FavoriteCount  AnswerCount
# 0      69257             28           11
# 1     113780             14            5
# 2      18382             19           11
# 3     550884           1357           24
# 4      56573             13            8

# %%
data.shape
# Out:
# (27933, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27933 entries, 0 to 27932
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          27933 non-null  object
#  1   Body           27933 non-null  object
#  2   Tags           27933 non-null  object
#  3   Id             27933 non-null  int64
#  4   Score          27933 non-null  int64
#  5   ViewCount      27933 non-null  int64
#  6   FavoriteCount  27933 non-null  int64
#  7   AnswerCount    27933 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 1.7+ MB

# %%
data.dtypes.value_counts()
# Out:
# int64     5
# object    3
# dtype: int64

# %%
data.nunique()
# Out:
# Title            27933
# Body             27933
# Tags             27447
# Id               27933
# Score             1095
# ViewCount        25519
# FavoriteCount      588
# AnswerCount         76
# dtype: int64

# %%
# NaN and duplicates
data.isna().sum()
# Out:
# Title            0
# Body             0
# Tags             0
# Id               0
# Score            0
# ViewCount        0
# FavoriteCount    0
# AnswerCount      0
# dtype: int64

# %%
data.duplicated(subset="Body").sum()
# Out:
# 0

# %%
for col in data.columns:
    n =data.duplicated(subset=col).sum()
    print(f"col:{col}-> duplicated:{n}")
# Out:
# col:Title-> duplicated:0
# col:Body-> duplicated:0
# col:Tags-> duplicated:486
# col:Id-> duplicated:0
# col:Score-> duplicated:26838
# col:ViewCount-> duplicated:2414
# col:FavoriteCount-> duplicated:27345
# col:AnswerCount-> duplicated:27857

# %%
data.duplicated(subset="Tags", keep ="first")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27928    False
# 27929    False
# 27930    False
# 27931    False
# 27932    False
# Length: 27933, dtype: bool

# %%
idx = data.duplicated(subset="Tags", keep="first")
data.loc[idx, :].sort_values("Tags")
# Out:
#                                                    Title  \
# 23904  "UNPROTECTED PRIVATE KEY FILE!" Error using SS...
# 26248  How can I modify ripple color when using ?attr...
# 25503             Got exception: fragment already active
# 3739       gen already exists but is not a source folder
# 5956   how append date build to versionNameSuffix on ...
# ...                                                  ...
# 24361        What is the 'shadow space' in x64 assembly?
# 24420             Variables are not behaving as expected
# 27355   Where is the Write-Combining Buffer located? x86
# 26789  xmlns, xmlns:xsi, xsi:schemaLocation, and targ...
# 17667        What is the difference between xsd and xsi?
#
#                                                     Body  \
# 23904  <p>I've created a new linux instance on Amazon...
# 26248  <p>I've seen some SO questions and they gave s...
# 25503  <p>I have a <strong>fragment</strong>;</p>\n\n...
# 3739   <p>I am developing my Android project, After I...
# 5956   <p>I am using Android Studio and I need to app...
# ...                                                  ...
# 24361  <p>I found plenty of topics about this shadow ...
# 24420  <p>I've been wrestling trying to get the synta...
# 27355  <p>How is the Write-Combine buffer physically ...
# 26789  <p>For the following XML fragment:</p>\n\n<pre...
# 17667  <p>What exactly is the difference between <str...
#
#                                                     Tags        Id  Score  \
# 23904  <amazon-web-services><authentication><ssh><ama...   8193768    915
# 26248  <android><android-layout><android-5.0-lollipop...  33061050    129
# 25503  <android><android-layout><android-intent><andr...  10364478     58
# 3739   <android><android-layout><android-intent><andr...   9532045     92
# 5956   <android><android-studio><gradle><android-grad...  19172565     89
# ...                                                  ...       ...    ...
# 24361  <windows><assembly><x86-64><calling-convention...  30190132     36
# 24420  <windows><batch-file><cmd><environment-variabl...  30282784     26
# 27355  <x86><intel><cpu-architecture><cpu-cache><amd-...  49959963     15
# 26789  <xml><xsd><xml-namespaces><xsd-validation><xml...  34202967     76
# 17667  <xml><xsd><xml-namespaces><xsd-validation><xml...  41035128     38
#
#        ViewCount  FavoriteCount  AnswerCount
# 23904     629086            214           41
# 26248      75463             50            8
# 25503      42096             15            8
# 3739       57301             22           15
# 5956       64171             20            7
# ...          ...            ...          ...
# 24361      15837             12            2
# 24420       9116             14            1
# 27355       5274             12            3
# 26789      59893             31            2
# 17667      45683             16            2
#
# [486 rows x 8 columns]

# %%
# Data Describe
data.describe(include=np.number)
# Out:
#                  Id         Score     ViewCount  FavoriteCount   AnswerCount
# count  2.793300e+04  27933.000000  2.793300e+04   27933.000000  27933.000000
# mean   1.690787e+07    114.001360  1.120698e+05      42.705044      7.154871
# std    1.541228e+07    351.730108  2.467875e+05     145.693052      6.789046
# min    4.000000e+00      6.000000  2.760000e+02      11.000000      1.000000
# 25%    4.211909e+06     29.000000  2.183900e+04      14.000000      3.000000
# 50%    1.213544e+07     51.000000  4.900500e+04      19.000000      5.000000
# 75%    2.618065e+07     99.000000  1.122840e+05      35.000000      9.000000
# max    7.290447e+07  26631.000000  1.030442e+07   11654.000000    128.000000

# %%
data.describe(include=object)
# Out:
#                                                     Title  \
# count                                               27933
# unique                                              27933
# top     Cannot load driver class: com.mysql.jdbc.Drive...
# freq                                                    1
#
#                                                      Body  \
# count                                               27933
# unique                                              27933
# top     <p>In previous versions of <code>Xcode</code> ...
# freq                                                    1
#
#                                                      Tags
# count                                               27933
# unique                                              27447
# top     <java><spring><jpa><spring-data><spring-data-jpa>
# freq                                                   19

# %%
cols = ["Id", "Title", "Body", "Tags"]
df =data[cols]
df.head()
# Out:
#         Id                                              Title  \
# 0     1898  Import CSV file to strongly typed data structu...
# 1  1939041               Change hash without reload in jQuery
# 2     2027                Pass by reference or pass by value?
# 3     2056   What are MVP and MVC and what is the difference?
# 4     2138                       LINQ on the .NET 2.0 Runtime
#
#                                                 Body  \
# 0  <p>What's the best way to import a CSV file in...
# 1  <p>I have the following code:</p>\n\n<pre><cod...
# 2  <p>When learning a new programming language, o...
# 3  <p>When looking beyond the <a href="https://en...
# 4  <p>Can a LINQ enabled app run on a machine tha...
#
#                                                 Tags
# 0                    <c#><vb.net><file><csv><import>
# 1  <jquery><hash><reload><fragment-identifier><wi...
# 2  <language-agnostic><oop><parameters><pass-by-r...
# 3  <user-interface><model-view-controller><design...
# 4              <.net><linq><.net-3.5><.net-2.0><clr>

# %%
df.to_csv("data_cleaned.csv")

# %%
pd.read_csv("data_cleaned.csv")
# Out:
#        Unnamed: 0        Id  \
# 0               0      1898
# 1               1   1939041
# 2               2      2027
# 3               3      2056
# 4               4      2138
# ...           ...       ...
# 27928       27928  37332190
# 27929       27929  37334668
# 27930       27930  55345373
# 27931       27931  55372259
# 27932       27932  55375803
#
#                                                    Title  \
# 0      Import CSV file to strongly typed data structu...
# 1                   Change hash without reload in jQuery
# 2                    Pass by reference or pass by value?
# 3       What are MVP and MVC and what is the difference?
# 4                           LINQ on the .NET 2.0 Runtime
# ...                                                  ...
# 27928                          Django - Login with Email
# 27929  Is there a python equivalent for RSpec to do TDD?
# 27930                 How to install GCC/G++ 8 on CentOS
# 27931    How to use TabLayout with ViewPager2 in Android
# 27932  Mystifying microbenchmark result for stream AP...
#
#                                                     Body  \
# 0      <p>What's the best way to import a CSV file in...
# 1      <p>I have the following code:</p>\n\n<pre><cod...
# 2      <p>When learning a new programming language, o...
# 3      <p>When looking beyond the <a href="https://en...
# 4      <p>Can a LINQ enabled app run on a machine tha...
# ...                                                  ...
# 27928  <p>I want django to authenticate users via ema...
# 27929  <p>I'm looking for a test framework like Ruby'...
# 27930  <p>I'm used to install packages on Debian/Ubun...
# 27931  <p>I want to use <code>com.google.android.mate...
# 27932  <p>As part of my investigation on the differen...
#
#                                                     Tags
# 0                        <c#><vb.net><file><csv><import>
# 1      <jquery><hash><reload><fragment-identifier><wi...
# 2      <language-agnostic><oop><parameters><pass-by-r...
# 3      <user-interface><model-view-controller><design...
# 4                  <.net><linq><.net-3.5><.net-2.0><clr>
# ...                                                  ...
# 27928  <python><python-3.x><django><django-authentica...
# 27929                <python><ruby><testing><rspec><tdd>
# 27930  <gcc><centos><g++><software-collections><redha...
# 27931  <java><android><androidx><android-tablayout><a...
# 27932    <java><java-stream><benchmarking><jmh><java-12>
#
# [27933 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27933 entries, 0 to 27932
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      27933 non-null  int64
#  1   Title   27933 non-null  object
#  2   Body    27933 non-null  object
#  3   Tags    27933 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 873.0+ KB

# %%
import nltk

# %%
#nltk.download('stopwords')

# %%
#nltk.download('punkt')

# %%
#nltk.download('wordnet')

# %%
#nltk.download('omw-1.4')

# %%
df = df[['Id', 'Title', 'Body', 'Tags']]

# %%
df=df.sample(frac=0.1)
df.shape
# Out:
# (2793, 4)

# %%
df=df.drop_duplicates()
df.dropna(inplace=True)
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ❓ **Question (Cleaning Text)** ❓
#
# - Write a function `preprocessing` that will clean a sentence and apply it to all our reviews. It should:
#     - remove whitespace
#     - lowercase characters
#     - remove numbers
#     - remove punctuation
#     - tokenize
#     - lemmatize
# - You can store the cleaned reviews into a column called `cleaned_reviews`.
# - Do not remove stopwords in this challenge, we will explain why in the section `3. N-gram modelling`

# %%
import string
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

def preprocessing(sentence):
    # $CHALLENGIFY_BEGIN

    # Removing whitespaces
    sentence = sentence.strip()    
    # Lowercasing
    sentence = sentence.lower()
    # Removing numbers
    sentence = ''.join(char for char in sentence if not char.isdigit())
    # Removing punctuation
    for punctuation in string.punctuation:
        sentence = sentence.replace(punctuation, '') 
    # Tokenizing
    tokenized = word_tokenize(sentence)
    # Lemmatizing
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(word) for word in tokenized]
    cleaned_sentence = " ".join(lemmatized)
    return cleaned_sentence

# %%
# Clean reviews
# $CHALLENGIFY_BEGIN
df['clean_title'] = df.Title.apply(preprocessing)
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c

# %%
df['clean_body'] = df.Body.apply(preprocessing)
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title  \
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c
#
#                                               clean_body
# 17073  pwhich is the best orm tool available for andr...
# 2667   pi came across some java code that had the fol...
# 27371  pi am trying to set a server agnostic date tim...
# 155    pi wrote a small web app using ruby on rail it...
# 21024  pare there any c or c libs that have numpylike...

# %%
import string
def remove_punctuation(Tags):
    for punctuation in string.punctuation:
        Tags = Tags.replace(punctuation, ' ')
    return Tags
df['clean_tags'] = df.Tags.apply(remove_punctuation)
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title  \
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c
#
#                                               clean_body  \
# 17073  pwhich is the best orm tool available for andr...
# 2667   pi came across some java code that had the fol...
# 27371  pi am trying to set a server agnostic date tim...
# 155    pi wrote a small web app using ruby on rail it...
# 21024  pare there any c or c libs that have numpylike...
#
#                                               clean_tags
# 17073   android  ormlite  greendao  activeandroid  dr...
# 2667    java  methods  parameters  overloading  defau...
# 27371   java  java 8  java util date  datetime conver...
# 155     ruby on rails  ruby  memory  memory leaks  co...
# 21024    c    arrays  python 3 x  numpy  dynamic arrays

# %%
def remove_numbers(Tags):
    words_only = ''.join([i for i in Tags if not i.isdigit()])
    return words_only
df['clean_tags'] = df.clean_tags.apply(remove_numbers)
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title  \
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c
#
#                                               clean_body  \
# 17073  pwhich is the best orm tool available for andr...
# 2667   pi came across some java code that had the fol...
# 27371  pi am trying to set a server agnostic date tim...
# 155    pi wrote a small web app using ruby on rail it...
# 21024  pare there any c or c libs that have numpylike...
#
#                                               clean_tags
# 17073   android  ormlite  greendao  activeandroid  dr...
# 2667    java  methods  parameters  overloading  defau...
# 27371   java  java   java util date  datetime convers...
# 155     ruby on rails  ruby  memory  memory leaks  co...
# 21024     c    arrays  python  x  numpy  dynamic arrays

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
stop_words = set(stopwords.words('english'))

def remove_stopwords(Tags):
    tokenized =word_tokenize(Tags)
    without_stopwords = [word for word in tokenized if not word in stop_words]
    return without_stopwords
df['clean_tags'] = df.clean_tags.apply(remove_stopwords)
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title  \
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c
#
#                                               clean_body  \
# 17073  pwhich is the best orm tool available for andr...
# 2667   pi came across some java code that had the fol...
# 27371  pi am trying to set a server agnostic date tim...
# 155    pi wrote a small web app using ruby on rail it...
# 21024  pare there any c or c libs that have numpylike...
#
#                                               clean_tags
# 17073  [android, ormlite, greendao, activeandroid, dr...
# 2667   [java, methods, parameters, overloading, defau...
# 27371  [java, java, java, util, date, datetime, conve...
# 155    [ruby, rails, ruby, memory, memory, leaks, cod...
# 21024     [c, arrays, python, x, numpy, dynamic, arrays]

# %%
from nltk.stem import WordNetLemmatizer
def lemma(Tags):
    lemmatizer = WordNetLemmatizer()# Instantiate lemmatizer
    lemmatized = [lemmatizer.lemmatize(word) for word in Tags]#Lemmatize
    lemmatized_string = ' '.join(lemmatized)
    return lemmatized_string
df['clean_tags'] = df.clean_tags.apply(lemma)
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title  \
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c
#
#                                               clean_body  \
# 17073  pwhich is the best orm tool available for andr...
# 2667   pi came across some java code that had the fol...
# 27371  pi am trying to set a server agnostic date tim...
# 155    pi wrote a small web app using ruby on rail it...
# 21024  pare there any c or c libs that have numpylike...
#
#                                               clean_tags
# 17073  android ormlite greendao activeandroid droidparts
# 2667   java method parameter overloading default para...
# 27371  java java java util date datetime conversion z...
# 155       ruby rail ruby memory memory leak coding style
# 21024               c array python x numpy dynamic array

# %% [markdown]
# # Analysis clean text

# %%
# reviey the dataset
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title  \
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c
#
#                                               clean_body  \
# 17073  pwhich is the best orm tool available for andr...
# 2667   pi came across some java code that had the fol...
# 27371  pi am trying to set a server agnostic date tim...
# 155    pi wrote a small web app using ruby on rail it...
# 21024  pare there any c or c libs that have numpylike...
#
#                                               clean_tags
# 17073  android ormlite greendao activeandroid droidparts
# 2667   java method parameter overloading default para...
# 27371  java java java util date datetime conversion z...
# 155       ruby rail ruby memory memory leak coding style
# 21024               c array python x numpy dynamic array

# %%
# check the data columns
df.columns
# Out:
# Index(['Id', 'Title', 'Body', 'Tags', 'clean_title', 'clean_body',
#        'clean_tags'],
#       dtype='object')

# %%
df['full_review'] =df['Title'].fillna('') + " " \
            + df['Body'].fillna('')

# %%
df.head()
# Out:
#              Id                                        Title  \
# 17073  13680954      Green DAO vs ORM lite vs Active Android
# 2667     997482  Does Java support default parameter values?
# 27371  32274369        How to convert ZonedDateTime to Date?
# 155      161315     ruby/ruby on rails memory leak detection
# 21024  11169418                  NumPy style arrays for C++?
#
#                                                     Body  \
# 17073  <p>Which is the best ORM tool available for An...
# 2667   <p>I came across some Java code that had the f...
# 27371  <p>I am trying to set a server agnostic date t...
# 155    <p>I wrote a small web app using ruby on rails...
# 21024  <p>Are there any C++ (or C) libs that have Num...
#
#                                                     Tags  \
# 17073  <android><ormlite><greendao><activeandroid><dr...
# 2667   <java><methods><parameters><overloading><defau...
# 27371  <java><java-8><java.util.date><datetime-conver...
# 155    <ruby-on-rails><ruby><memory><memory-leaks><co...
# 21024   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                     clean_title  \
# 17073     green dao v orm lite v active android
# 2667   doe java support default parameter value
# 27371      how to convert zoneddatetime to date
# 155      rubyruby on rail memory leak detection
# 21024                   numpy style array for c
#
#                                               clean_body  \
# 17073  pwhich is the best orm tool available for andr...
# 2667   pi came across some java code that had the fol...
# 27371  pi am trying to set a server agnostic date tim...
# 155    pi wrote a small web app using ruby on rail it...
# 21024  pare there any c or c libs that have numpylike...
#
#                                               clean_tags  \
# 17073  android ormlite greendao activeandroid droidparts
# 2667   java method parameter overloading default para...
# 27371  java java java util date datetime conversion z...
# 155       ruby rail ruby memory memory leak coding style
# 21024               c array python x numpy dynamic array
#
#                                              full_review
# 17073  Green DAO vs ORM lite vs Active Android <p>Whi...
# 2667   Does Java support default parameter values? <p...
# 27371  How to convert ZonedDateTime to Date? <p>I am ...
# 155    ruby/ruby on rails memory leak detection <p>I ...
# 21024  NumPy style arrays for C++? <p>Are there any C...

# %%
df.shape
# Out:
# (2793, 8)

# %%
df = df.reset_index(drop = True)

# %%
df.head()
# Out:
#          Id                                        Title  \
# 0  13680954      Green DAO vs ORM lite vs Active Android
# 1    997482  Does Java support default parameter values?
# 2  32274369        How to convert ZonedDateTime to Date?
# 3    161315     ruby/ruby on rails memory leak detection
# 4  11169418                  NumPy style arrays for C++?
#
#                                                 Body  \
# 0  <p>Which is the best ORM tool available for An...
# 1  <p>I came across some Java code that had the f...
# 2  <p>I am trying to set a server agnostic date t...
# 3  <p>I wrote a small web app using ruby on rails...
# 4  <p>Are there any C++ (or C) libs that have Num...
#
#                                                 Tags  \
# 0  <android><ormlite><greendao><activeandroid><dr...
# 1  <java><methods><parameters><overloading><defau...
# 2  <java><java-8><java.util.date><datetime-conver...
# 3  <ruby-on-rails><ruby><memory><memory-leaks><co...
# 4   <c++><arrays><python-3.x><numpy><dynamic-arrays>
#
#                                 clean_title  \
# 0     green dao v orm lite v active android
# 1  doe java support default parameter value
# 2      how to convert zoneddatetime to date
# 3    rubyruby on rail memory leak detection
# 4                   numpy style array for c
#
#                                           clean_body  \
# 0  pwhich is the best orm tool available for andr...
# 1  pi came across some java code that had the fol...
# 2  pi am trying to set a server agnostic date tim...
# 3  pi wrote a small web app using ruby on rail it...
# 4  pare there any c or c libs that have numpylike...
#
#                                           clean_tags  \
# 0  android ormlite greendao activeandroid droidparts
# 1  java method parameter overloading default para...
# 2  java java java util date datetime conversion z...
# 3     ruby rail ruby memory memory leak coding style
# 4               c array python x numpy dynamic array
#
#                                          full_review
# 0  Green DAO vs ORM lite vs Active Android <p>Whi...
# 1  Does Java support default parameter values? <p...
# 2  How to convert ZonedDateTime to Date? <p>I am ...
# 3  ruby/ruby on rails memory leak detection <p>I ...
# 4  NumPy style arrays for C++? <p>Are there any C...

# %%
df['clean_tags'].shape
# Out:
# (2793,)

# %%
## https://www.kaggle.com/code/anubhavpoonia/notebook9e650d573f

# %% [markdown]
# # New Dataframe

# %%
df1 = df[['Id','full_review', 'clean_tags']]

# %%
df1
# Out:
#             Id                                        full_review  \
# 0     13680954  Green DAO vs ORM lite vs Active Android <p>Whi...
# 1       997482  Does Java support default parameter values? <p...
# 2     32274369  How to convert ZonedDateTime to Date? <p>I am ...
# 3       161315  ruby/ruby on rails memory leak detection <p>I ...
# 4     11169418  NumPy style arrays for C++? <p>Are there any C...
# ...        ...                                                ...
# 2788  35884752  Error in slick.js: "Uncaught TypeError: Cannot...
# 2789  44392027  webRTC convert webm to mp4 with ffmpeg.js <p>I...
# 2790  12042853  Difference between "MapHttpRoute" and "MapRout...
# 2791  46551268  When the keyboard appears, the Flutter widgets...
# 2792  22453273  How to visualize a large network in R? <p>Netw...
#
#                                              clean_tags
# 0     android ormlite greendao activeandroid droidparts
# 1     java method parameter overloading default para...
# 2     java java java util date datetime conversion z...
# 3        ruby rail ruby memory memory leak coding style
# 4                  c array python x numpy dynamic array
# ...                                                 ...
# 2788        jquery ruby rail slider nested form slick j
# 2789         ffmpeg webrtc mp mediarecorder mediastream
# 2790  c asp net asp net mvc asp net web api asp net ...
# 2791           keyboard resize widget textfield flutter
# 2792  r graph visualization social networking graph ...
#
# [2793 rows x 3 columns]

# %% [markdown]
# ## Tags

# %% [markdown]
# Let's do some cleaning on the tags' column. Furthermore, I decided to keep the 100 most popular tags because I'll be easier to predict the right tag from 100 words than from 14,000 and because we want to keep macro tags and not be too specific since it's only a recommendation for a post, the user can add more specific tags himself.

# %%
df1['Tags'] = df1['clean_tags'].apply(lambda x: x.split())
# Out:
# <ipython-input-47-6894cd55bcd5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Tags'] = df1['clean_tags'].apply(lambda x: x.split())

# %%
all_tags = [item for sublist in df1['clean_tags'].values for item in sublist]

# %%
my_set = set(all_tags)
unique_tags = list(my_set)
len(unique_tags)
# Out:
# 27

# %%
flat_list = [item for sublist in df1['Tags'].values for item in sublist]

keywords = nltk.FreqDist(flat_list)

keywords = nltk.FreqDist(keywords)

frequencies_words = keywords.most_common(100)
tags_features = [word[0] for word in frequencies_words]

# %%
tags_features
# Out:
# ['c',
#  'android',
#  'python',
#  'java',
#  'net',
#  'io',
#  'javascript',
#  'asp',
#  'spring',
#  'sql',
#  'iphone',
#  'objective',
#  'html',
#  'ruby',
#  'jquery',
#  'mvc',
#  'studio',
#  'window',
#  'j',
#  'xcode',
#  'google',
#  'web',
#  'php',
#  'linux',
#  'server',
#  'django',
#  'rail',
#  'visual',
#  'data',
#  'git',
#  'performance',
#  'database',
#  'api',
#  'framework',
#  'image',
#  'node',
#  'swift',
#  'file',
#  'cs',
#  'array',
#  'http',
#  'x',
#  'string',
#  'memory',
#  'multithreading',
#  'mysql',
#  'service',
#  'entity',
#  'cocoa',
#  'algorithm',
#  'amazon',
#  'json',
#  'gradle',
#  'core',
#  'design',
#  'apache',
#  'numpy',
#  'security',
#  'rest',
#  'authentication',
#  'bash',
#  'video',
#  'processing',
#  'r',
#  'function',
#  'xml',
#  'panda',
#  'touch',
#  'code',
#  'learning',
#  'facebook',
#  'testing',
#  'wpf',
#  'type',
#  'macos',
#  'laravel',
#  'library',
#  'build',
#  'jpa',
#  'mongodb',
#  'interface',
#  'chrome',
#  'optimization',
#  'postgresql',
#  'ajax',
#  'spark',
#  'maven',
#  'eclipse',
#  'selenium',
#  'shell',
#  'line',
#  'reactjs',
#  'ubuntu',
#  'layout',
#  'angular',
#  'class',
#  'command',
#  'event',
#  'hibernate',
#  'dataframe']

# %%
fig, ax = plt.subplots(figsize=(15, 10))
keywords.plot(50, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
def most_common(tags):
    tags_filtered = []
    for i in range(0, len(tags)):
        if tags[i] in tags_features:
            tags_filtered.append(tags[i])
    return tags_filtered

# %%
df1['Tags'] = df1['Tags'].apply(lambda x: most_common(x))
df1['Tags'] = df1['Tags'].apply(lambda x: x if len(x)>0 else None)
# Out:
# <ipython-input-54-ce9b8bb6ea07>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Tags'] = df1['Tags'].apply(lambda x: most_common(x))
# <ipython-input-54-ce9b8bb6ea07>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Tags'] = df1['Tags'].apply(lambda x: x if len(x)>0 else None)

# %%
df1.shape
# Out:
# (2793, 4)

# %%
df1.dropna(subset=['Tags'], inplace=True)
# Out:
# <ipython-input-56-a1990f25471c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(subset=['Tags'], inplace=True)

# %%
df1.shape
# Out:
# (2704, 4)

# %%
df1.head()
# Out:
#          Id                                        full_review  \
# 0  13680954  Green DAO vs ORM lite vs Active Android <p>Whi...
# 1    997482  Does Java support default parameter values? <p...
# 2  32274369  How to convert ZonedDateTime to Date? <p>I am ...
# 3    161315  ruby/ruby on rails memory leak detection <p>I ...
# 4  11169418  NumPy style arrays for C++? <p>Are there any C...
#
#                                           clean_tags  \
# 0  android ormlite greendao activeandroid droidparts
# 1  java method parameter overloading default para...
# 2  java java java util date datetime conversion z...
# 3     ruby rail ruby memory memory leak coding style
# 4               c array python x numpy dynamic array
#
#                                   Tags
# 0                            [android]
# 1                               [java]
# 2                   [java, java, java]
# 3   [ruby, rail, ruby, memory, memory]
# 4  [c, array, python, x, numpy, array]

# %% [markdown]
# ## Title + Body = full_review

# %% [markdown]
# In the next two columns: Body and Title, I'll use lots of text processing:
# ````
# Removing html format
# Lowering text
# Transforming abbreviations
# Removing punctuation (but keeping words like c# since it's the most popular tag)
# Lemmatizing words
# Removing stop words``
# ````

# %%
import re

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "can not ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"\'scuse", " excuse ", text)
    text = re.sub(r"\'\n", " ", text)
    text = re.sub(r"\'\xa0", " ", text)
    text = re.sub('\s+', ' ', text)
    text = text.strip(' ')
    return text

# %%
df1['full_review'] = df1['full_review'].apply(lambda x: clean_text(x))
# Out:
# <ipython-input-61-d71aa47ab089>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['full_review'] = df1['full_review'].apply(lambda x: clean_text(x))

# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns

import warnings

import pickle
import time

import re
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import ToktokTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from string import punctuation

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import hamming_loss
from sklearn.cluster import KMeans


import logging

from scipy.sparse import hstack

warnings.filterwarnings("ignore")
plt.style.use('bmh')
# %matplotlib inline

# %%
token=ToktokTokenizer()

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punct = '!"#$%&\'()*+,./:;<=>?@[\\]^_`{|}~'

# %%
def strip_list_noempty(mylist):
    newlist = (item.strip() if hasattr(item, 'strip') else item for item in mylist)
    return [item for item in newlist if item != '']

# %%
def clean_punct(text): 
    words=token.tokenize(text)
    punctuation_filtered = []
    regex = re.compile('[%s]' % re.escape(punct))
    remove_punctuation = str.maketrans(' ', ' ', punct)
    for w in words:
        if w in tags_features:
            punctuation_filtered.append(w)
        else:
            punctuation_filtered.append(regex.sub('', w))
  
    filtered_list = strip_list_noempty(punctuation_filtered)
        
    return ' '.join(map(str, filtered_list))

# %%
df1['full_review'][2]
# Out:
# 'how to convert zoneddatetime to date? <p>i am trying to set a server agnostic date time in my database and i believe the best practice to do so is to set a utc datetime. my db server is cassandra and the db driver for java understands only the date type.</p> <p>so assuming that in my code i am using the new java 8 zoneddatetime to get the utc now (<code>zoneddatetime.now(zoneoffset.utc)</code>), how can i convert this zoneddatetime instance to the "legacy" date class?</p>'

# %%
df1['full_review'] = df1['full_review'].apply(lambda x: clean_punct(x))

# %%
df1['full_review'][2]
# Out:
# 'how to convert zoneddatetime to date pi am trying to set a server agnostic date time in my database and i believe the best practice to do so is to set a utc datetime my db server is cassandra and the db driver for java understands only the date typep pso assuming that in my code i am using the new java 8 zoneddatetime to get the utc now codezoneddatetimenow zoneoffsetutc code how can i convert this zoneddatetime instance to the legacy date classp'

# %%
lemma=WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

# %%
def lemitizeWords(text):
    words=token.tokenize(text)
    listLemma=[]
    for w in words:
        x=lemma.lemmatize(w, pos="v")
        listLemma.append(x)
    return ' '.join(map(str, listLemma))

def stopWordsRemove(text):
    stop_words = set(stopwords.words("english"))
    words=token.tokenize(text)
    filtered = [w for w in words if not w in stop_words]
    return ' '.join(map(str, filtered))

# %%
df1['full_review'] = df1['full_review'].apply(lambda x: lemitizeWords(x)) 
df1['full_review'] = df1['full_review'].apply(lambda x: stopWordsRemove(x))

# %% [markdown]
# # LDA

# %% [markdown]
# Here I'll just use some LDA to see if shows any paterns in words and the main topics.

# %%
n_components=20

# %%
text = df1['full_review']

# %%
vectorizer_train = TfidfVectorizer(analyzer = 'word',
                                       min_df=0.0,
                                       max_df = 1.0,
                                       strip_accents = None,
                                       encoding = 'utf-8', 
                                       preprocessor=None,
                                       token_pattern=r"(?u)\S\S+",
                                       max_features=1000)

# %%
TF_IDF_matrix = vectorizer_train.fit_transform(text)

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
lda = LatentDirichletAllocation(n_components=20, max_iter=5, learning_method='online', learning_offset=50,random_state=11).fit(TF_IDF_matrix)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("--------------------------------------------")
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print("--------------------------------------------")
        

no_top_words = 10
display_topics(lda, vectorizer_train.get_feature_names(), no_top_words)
# Out:
# --------------------------------------------
# Topic 0:
# lt gt facebook artifactidgt groupidgt web class filename divgt stringgt
# --------------------------------------------
# --------------------------------------------
# Topic 1:
# 124 orientation row branch table master image codepre count product
# --------------------------------------------
# --------------------------------------------
# Topic 2:
# l2 l1 df would code pandas store lt output divgt
# --------------------------------------------
# --------------------------------------------
# Topic 3:
# ptr eax mov char double int operator lt assign commit
# --------------------------------------------
# --------------------------------------------
# Topic 4:
# resultingangles bar float cache tab address strong change level color
# --------------------------------------------
# --------------------------------------------
# Topic 5:
# add cpu share task git use bite change array code
# --------------------------------------------
# --------------------------------------------
# Topic 6:
# space html net file variables status code new coordinate shell
# --------------------------------------------
# --------------------------------------------
# Topic 7:
# save npm model object result def get data response err
# --------------------------------------------
# --------------------------------------------
# Topic 8:
# class every attribute think difference real platform develop things python
# --------------------------------------------
# --------------------------------------------
# Topic 9:
# 2019-12-06t00 web1 00 30 code index gt run container use
# --------------------------------------------
# --------------------------------------------
# Topic 10:
# nan 01 05 float dataframe codepre pandas use extract operator
# --------------------------------------------
# --------------------------------------------
# Topic 11:
# windows python primary development 00 hash string lt key gt
# --------------------------------------------
# --------------------------------------------
# Topic 12:
# android layoutwidth layoutheight matchparent wrapcontent textview xmlns layout lt gt
# --------------------------------------------
# --------------------------------------------
# Topic 13:
# string mysql block data var drop use default ios java
# --------------------------------------------
# --------------------------------------------
# Topic 14:
# default box interface disable image ajax attribute present part application
# --------------------------------------------
# --------------------------------------------
# Topic 15:
# use pi file href code codepre lt would rel noreferrer
# --------------------------------------------
# --------------------------------------------
# Topic 16:
# class public lt codepre string return name type private int
# --------------------------------------------
# --------------------------------------------
# Topic 17:
# mean data layer gradle new fix explain little use draw
# --------------------------------------------
# --------------------------------------------
# Topic 18:
# gt import android plot function lt model audio line nofollow
# --------------------------------------------
# --------------------------------------------
# Topic 19:
# header http phow arguments 40 net web quot custom client
# --------------------------------------------

# %% [markdown]
# # Classical classifiers

# %% [markdown]
# ## Multi-label classification
#
# https://en.wikipedia.org/wiki/Multi-label_classification
#
# In machine learning, multi-label classification or multi-output classification is a variant of the classification problem where multiple nonexclusive labels may be assigned to each instance. Multi-label classification is a generalization of multiclass classification, which is the single-label problem of categorizing instances into precisely one of several (more than two) classes. In the multi-label problem the labels are nonexclusive and there is no constraint on how many of the classes the instance can be assigned to.
#
# Formally, multi-label classification is the problem of finding a model that maps inputs x to binary vectors y; that is, it assigns a value of 0 or 1 for each element (label) in y.
#
# Statistics and evaluation metrics
#
# Hamming loss
#
# Hamming loss: the fraction of the wrong labels to the total number of labels, i.e. {\displaystyle {\frac {1}{|N|\cdot |L|}}\sum _{i=1}^{|N|}\sum _{j=1}^{|L|}\operatorname {xor} (y_{i,j},z_{i,j})}{\displaystyle {\frac {1}{|N|\cdot |L|}}\sum _{i=1}^{|N|}\sum _{j=1}^{|L|}\operatorname {xor} (y_{i,j},z_{i,j})}, where {\displaystyle y_{i,j}}y_{i,j} is the target, {\displaystyle z_{i,j}}z_{{i,j}} is the prediction, and {\displaystyle \operatorname {xor} (\cdot )}{\displaystyle \operatorname {xor} (\cdot )} is the "Exclusive, or" operator that returns zero when the target and prediction are identical and one otherwise. This is a loss function, so the optimal value is zero and its upper bound is one.
#
# In information theory, the Hamming distance between two strings of equal length is the number of positions at which the corresponding symbols are different. In other words, it measures the minimum number of substitutions required to change one string into the other, or the minimum number of errors that could have transformed one string into the other. In a more general context, the Hamming distance is one of several string metrics for measuring the edit distance between two sequences. It is named after the American mathematician Richard Hamming.
#
# Jaccard index
#
# The closely related Jaccard index, also called Intersection over Union in the multi-label setting, is defined as the number of correctly predicted labels divided by the union of predicted and true labels, {\displaystyle {\frac {|T\cap P|}{|T\cup P|}}}{\frac  {|T\cap P|}{|T\cup P|}}, where {\displaystyle P}P and {\displaystyle T}T are sets of predicted labels and true labels respectively.

# %% [markdown]
# Data preparation

# %% [markdown]
# Now our data is almost ready to be put into a classifier. I just need to:
# ````
# Binarize the tags
# Use a TFIDF for body and Title The parameters in the TFIDF are very important for the performance of our tags since we don't want him to delete words like c# or.net. To do that we need to use the following pattern : token_pattern=r"(?u)\S\S+"
# ````

# %% [markdown]
# # TFIDF

# %%
df1.shape
# Out:
# (2704, 4)

# %%
X = df1['full_review']
y = df1['Tags']

# %%
X.shape
# Out:
# (2704,)

# %%
y.shape
# Out:
# (2704,)

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %%
vectorizer_X = TfidfVectorizer(analyzer = 'word',
                                       min_df=0.0,
                                       max_df = 1.0,
                                       strip_accents = None,
                                       encoding = 'utf-8', 
                                       preprocessor=None,
                                       token_pattern=r"(?u)\S\S+",
                                       max_features=1000)

# %%
X_tfidf = vectorizer_X.fit_transform(X)

# %%
X_tfidf
# Out:
# <2704x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 107055 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import PCA,TruncatedSVD

# %%
clf = TruncatedSVD(500)
Xpca = clf.fit_transform(X_tfidf)

# %%
Xpca
# Out:
# array([[ 0.13322274, -0.03259079,  0.08214148, ..., -0.01943147,
#          0.00557274,  0.015934  ],
#        [ 0.21243924,  0.00653572, -0.19865459, ...,  0.03204969,
#         -0.01891055, -0.00772272],
#        [ 0.17837333, -0.06063648, -0.10476132, ...,  0.00077653,
#          0.00115362, -0.0014474 ],
#        ...,
#        [ 0.34573155,  0.74030333,  0.11668369, ...,  0.01169737,
#          0.02216459,  0.00406588],
#        [ 0.13608293,  0.01321416, -0.09108932, ...,  0.01426911,
#         -0.04005122,  0.02547474],
#        [ 0.25943939, -0.05213166,  0.25209965, ..., -0.03333519,
#         -0.05174372,  0.04793125]])

# %%
clf.explained_variance_ratio_
# Out:
# array([0.00483195, 0.01727107, 0.01106402, 0.00974858, 0.00862799,
#        0.00842702, 0.0076526 , 0.00736651, 0.0067844 , 0.00660884,
#        0.00639619, 0.00622029, 0.00557823, 0.00547655, 0.00517411,
#        0.0049933 , 0.00489471, 0.00479386, 0.00477876, 0.00463548,
#        0.00448441, 0.00445144, 0.00442457, 0.00429565, 0.00421243,
#        0.00415293, 0.00413781, 0.00408494, 0.00397384, 0.00393557,
#        0.00384738, 0.00374927, 0.00371822, 0.00365298, 0.00362781,
#        0.00359777, 0.00355571, 0.00347709, 0.00345991, 0.0034173 ,
#        0.00339034, 0.00336436, 0.00334188, 0.00330052, 0.00328516,
#        0.00323586, 0.00317415, 0.00316372, 0.0031386 , 0.00312253,
#        0.00306592, 0.00303216, 0.00303177, 0.0029825 , 0.00294397,
#        0.00293483, 0.00290233, 0.00288652, 0.00286531, 0.0028279 ,
#        0.00281141, 0.00279334, 0.00277923, 0.00275168, 0.00270916,
#        0.00269353, 0.00266401, 0.00265776, 0.0026325 , 0.00261796,
#        0.00260893, 0.00259451, 0.00257677, 0.00256119, 0.00253415,
#        0.00251888, 0.00250894, 0.00248753, 0.00247325, 0.00244909,
#        0.00244311, 0.00243264, 0.00240903, 0.00238682, 0.00236754,
#        0.00235988, 0.00234665, 0.00233591, 0.00232558, 0.00230796,
#        0.00229391, 0.00229178, 0.00228248, 0.00226388, 0.00226044,
#        0.00223928, 0.00222096, 0.00221189, 0.00220543, 0.00219142,
#        0.00218392, 0.00217103, 0.00216   , 0.00215239, 0.00213486,
#        0.00212351, 0.00211819, 0.00210083, 0.00209568, 0.00208186,
#        0.00208039, 0.00206701, 0.00205569, 0.00205629, 0.00203942,
#        0.00202638, 0.00201877, 0.00201365, 0.00199254, 0.0019908 ,
#        0.00198211, 0.0019759 , 0.00197297, 0.00195791, 0.00195665,
#        0.00194797, 0.00193423, 0.0019262 , 0.00191549, 0.00191462,
#        0.00190499, 0.00189362, 0.00188891, 0.00187902, 0.00187574,
#        0.00186888, 0.00185392, 0.00184432, 0.00183663, 0.00182743,
#        0.00182179, 0.00181771, 0.00181435, 0.00181028, 0.00180709,
#        0.0017941 , 0.0017918 , 0.0017882 , 0.00177856, 0.00176977,
#        0.00176603, 0.00175914, 0.00175335, 0.00174431, 0.00173631,
#        0.00173429, 0.00172569, 0.00171632, 0.00171235, 0.00170727,
#        0.00170123, 0.00169181, 0.00168626, 0.00167959, 0.00167344,
#        0.00167026, 0.00165815, 0.00165301, 0.00164812, 0.00163767,
#        0.00163255, 0.0016214 , 0.00161677, 0.00160581, 0.0016016 ,
#        0.00159764, 0.00159254, 0.0015877 , 0.00158603, 0.00157674,
#        0.00156702, 0.00156369, 0.0015583 , 0.00155492, 0.00154943,
#        0.00153812, 0.00153419, 0.00152987, 0.0015245 , 0.00152007,
#        0.00151414, 0.00150951, 0.00150475, 0.00150252, 0.00149165,
#        0.00148728, 0.00148533, 0.00148287, 0.00147999, 0.0014703 ,
#        0.00146984, 0.00146524, 0.00145621, 0.00145556, 0.00144923,
#        0.00144473, 0.00143566, 0.00142837, 0.00142729, 0.00142404,
#        0.00141937, 0.00141377, 0.00140781, 0.00140437, 0.00139944,
#        0.00139374, 0.00138862, 0.00138613, 0.00137979, 0.00137697,
#        0.00137451, 0.00136697, 0.0013632 , 0.00135913, 0.00135402,
#        0.00134921, 0.00134488, 0.00134261, 0.00133983, 0.00133412,
#        0.00133104, 0.00132795, 0.00132399, 0.00131871, 0.00131391,
#        0.00131227, 0.00130326, 0.00130134, 0.00129678, 0.00129414,
#        0.00129227, 0.00128606, 0.00127724, 0.00127181, 0.00126761,
#        0.00126295, 0.00126094, 0.00125629, 0.0012547 , 0.00125178,
#        0.00124847, 0.00124737, 0.00124344, 0.00123743, 0.00123358,
#        0.00122921, 0.00122698, 0.00122102, 0.00121944, 0.00121491,
#        0.00120943, 0.00120535, 0.00120261, 0.00120049, 0.00119847,
#        0.00119433, 0.00119159, 0.00118612, 0.00118395, 0.0011788 ,
#        0.00117777, 0.00117376, 0.00117226, 0.00116633, 0.00116177,
#        0.00116056, 0.0011586 , 0.00115187, 0.00115004, 0.00114708,
#        0.00114121, 0.00114042, 0.00113594, 0.00113131, 0.00112978,
#        0.0011257 , 0.00112219, 0.00111906, 0.00111708, 0.00111325,
#        0.00110923, 0.00110397, 0.00110155, 0.00109873, 0.00109546,
#        0.00109255, 0.00108729, 0.00108555, 0.0010828 , 0.00107824,
#        0.0010752 , 0.00107362, 0.00107272, 0.00106736, 0.0010661 ,
#        0.00106378, 0.00105633, 0.00105278, 0.0010508 , 0.00104903,
#        0.00104694, 0.00104257, 0.00103907, 0.001037  , 0.00103429,
#        0.00103164, 0.00102666, 0.00102406, 0.00102283, 0.00102092,
#        0.00101847, 0.00101362, 0.00101165, 0.00100784, 0.00100728,
#        0.00100365, 0.00100335, 0.00099871, 0.00099534, 0.00099446,
#        0.00099215, 0.00099164, 0.00098733, 0.00098435, 0.00098076,
#        0.00097642, 0.00097598, 0.00097379, 0.00096935, 0.00096535,
#        0.00096317, 0.0009591 , 0.00095757, 0.00095656, 0.00095403,
#        0.00095068, 0.00094756, 0.00094236, 0.00093964, 0.00093814,
#        0.00093671, 0.00093268, 0.00092903, 0.00092758, 0.00092594,
#        0.00092302, 0.0009222 , 0.00091525, 0.00091297, 0.00091031,
#        0.00090938, 0.00090671, 0.00090266, 0.00090075, 0.00089982,
#        0.00089623, 0.00089429, 0.00089334, 0.00088998, 0.00088798,
#        0.00088635, 0.00088343, 0.00088152, 0.00087864, 0.00087713,
#        0.00087608, 0.00087465, 0.00086773, 0.00086663, 0.00086454,
#        0.00086285, 0.0008615 , 0.00086073, 0.00085432, 0.00085341,
#        0.00085242, 0.00084667, 0.00084302, 0.0008423 , 0.00083876,
#        0.00083818, 0.00083492, 0.00083447, 0.00083093, 0.00082826,
#        0.00082517, 0.00082176, 0.00082065, 0.00081875, 0.00081586,
#        0.00081455, 0.00081176, 0.00080997, 0.00080725, 0.00080519,
#        0.00080303, 0.00080028, 0.00079526, 0.00079304, 0.00079075,
#        0.00078927, 0.00078787, 0.00078605, 0.00078376, 0.00078259,
#        0.00077902, 0.00077709, 0.00077466, 0.00077259, 0.00076962,
#        0.00076808, 0.00076493, 0.00076032, 0.00075789, 0.00075743,
#        0.00075435, 0.00075238, 0.00074777, 0.00074618, 0.00074542,
#        0.00074372, 0.00074233, 0.00073803, 0.00073559, 0.00073414,
#        0.00072975, 0.00072672, 0.00072462, 0.00072316, 0.00072194,
#        0.00072144, 0.00071771, 0.0007139 , 0.0007104 , 0.00070959,
#        0.0007101 , 0.00070481, 0.00070247, 0.00069924, 0.00069662,
#        0.00069448, 0.00069102, 0.00068946, 0.00068753, 0.00068708,
#        0.00068342, 0.00068277, 0.00068006, 0.00067825, 0.00067712,
#        0.00067335, 0.00067259, 0.0006698 , 0.00066686, 0.00066605,
#        0.00066402, 0.00066202, 0.00065916, 0.0006582 , 0.00065765,
#        0.00065522, 0.00064991, 0.00064796, 0.00064506, 0.00064403,
#        0.00064317, 0.00063405, 0.00063297, 0.0006323 , 0.00062931,
#        0.00062826, 0.00062627, 0.00062441, 0.00062228, 0.00061924,
#        0.00061838, 0.00061383, 0.00061172, 0.00060832, 0.00060583,
#        0.00060241, 0.00059852, 0.00059738, 0.00059486, 0.00059191,
#        0.00058805, 0.00058655, 0.00058335, 0.00058191, 0.00057953])

# %%
#import des librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, 501), clf.explained_variance_ratio_.cumsum(),marker = "o", linestyle = "--")
plt.title("Explained Variance by Componants")
plt.xlabel("Nomber of componants")
plt.ylabel("Explained Variance")
# Out:
# Text(0, 0.5, 'Explained Variance')

# %%
# We are going to take 400 variables

# %%
clf = TruncatedSVD(300)
Xpca_tfidf = clf.fit_transform(X_tfidf)

# %%
Xpca_tfidf.shape
# Out:
# (2704, 300)

# %%
y_bin.shape
# Out:
# (2704, 100)

# %%
# 80/20 split
X_train, X_test, y_train, y_test = train_test_split(Xpca_tfidf, y_bin, test_size = 0.2, random_state = 0)

# %% [markdown]
# Now it's finally ready.

# %% [markdown]
# # One vs Rest

# %% [markdown]
# To evaluate our models, I'll use the jacard score since it's the best fitted for multi label classification.
# Hamming Loss is mostly relevant to Multi-label classification

# %%
def avg_jacard(y_true,y_pred):
    jacard = np.minimum(y_true,y_pred).sum(axis=1) / np.maximum(y_true,y_pred).sum(axis=1)    
    return jacard.mean()*100
    
def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    print("Jacard score: {}".format(avg_jacard(y_test, y_pred)))
    print("Hamming loss: {}".format(hamming_loss(y_pred, y_test)*100))
    print("---")

# %%
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.svm import LinearSVC
dummy = DummyClassifier()
sgd = SGDClassifier()
lr = LogisticRegression()
#mn = MultinomialNB()
svc = LinearSVC()
perceptron = Perceptron()
pac = PassiveAggressiveClassifier()

for classifier in [dummy, sgd, lr, svc, perceptron, pac]:
    clf = OneVsRestClassifier(classifier)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print_score(y_pred, classifier)
# Out:
# Clf:  DummyClassifier
# Jacard score: 0.0
# Hamming loss: 2.589648798521257
# ---
# Clf:  SGDClassifier
# Jacard score: 37.31471701434732
# Hamming loss: 1.9463955637707948
# ---
# Clf:  LogisticRegression
# Jacard score: 10.682598362820174
# Hamming loss: 2.3955637707948245
# ---
# Clf:  LinearSVC
# Jacard score: 33.3331866326321
# Hamming loss: 1.9463955637707948
# ---
# Clf:  Perceptron
# Jacard score: 30.654798579937214
# Hamming loss: 2.578558225508318
# ---
# Clf:  PassiveAggressiveClassifier
# Jacard score: 33.7300120294575
# Hamming loss: 2.567467652495379
# ---

# %% [markdown]
# SGDClassifier

# %%
sgd = SGDClassifier()
clf = OneVsRestClassifier(sgd)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, sgd)
# Out:
# Clf:  SGDClassifier
# Jacard score: 34.86921632485403
# Hamming loss: 1.9519408502772646
# ---

# %% [markdown]
# OneVsRestClassifier

# %%
lr = LogisticRegression()

clf = OneVsRestClassifier(lr)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, lr)
# Out:
# Clf:  LogisticRegression
# Jacard score: 10.682598362820174
# Hamming loss: 2.3955637707948245
# ---

# %% [markdown]
# RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

print_score(y_pred, rfc)
# Out:
# Clf:  RandomForestClassifier
# Jacard score: 2.831176833025262
# Hamming loss: 2.543438077634011
# ---

# %%
#https://www.kaggle.com/code/miljan/predicting-tags-for-stackoverflow

# %% [markdown]
# MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier()
mlpc.fit(X_train, y_train)

y_pred = mlpc.predict(X_test)

print_score(y_pred, mlpc)
# Out:
# Clf:  MLPClassifier
# Jacard score: 34.28989525569932
# Hamming loss: 2.0
# ---

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

print_score(y_pred, rfc)
# Out:
# Clf:  RandomForestClassifier
# Jacard score: 2.8003696857670977
# Hamming loss: 2.539741219963031
# ---

# %% [markdown]
# GridSearch CV on the best classifier

# %%
param_grid = {'estimator__C':[1,10,100,1000]
              }

# %%
svc = OneVsRestClassifier(LinearSVC())
CV_svc = model_selection.GridSearchCV(estimator=svc, param_grid=param_grid, cv= 5, verbose=10, scoring=make_scorer(avg_jacard,greater_is_better=True))
CV_svc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START estimator__C=1..............................................
# [CV 1/5; 1/4] END ..............estimator__C=1;, score=29.684 total time=   1.8s
# [CV 2/5; 1/4] START estimator__C=1..............................................
# [CV 2/5; 1/4] END ..............estimator__C=1;, score=30.322 total time=   1.8s
# [CV 3/5; 1/4] START estimator__C=1..............................................
# [CV 3/5; 1/4] END ..............estimator__C=1;, score=29.691 total time=   1.8s
# [CV 4/5; 1/4] START estimator__C=1..............................................
# [CV 4/5; 1/4] END ..............estimator__C=1;, score=32.365 total time=   1.8s
# [CV 5/5; 1/4] START estimator__C=1..............................................
# [CV 5/5; 1/4] END ..............estimator__C=1;, score=32.229 total time=   1.8s
# [CV 1/5; 2/4] START estimator__C=10.............................................
# [CV 1/5; 2/4] END .............estimator__C=10;, score=31.942 total time=   3.9s
# [CV 2/5; 2/4] START estimator__C=10.............................................
# [CV 2/5; 2/4] END .............estimator__C=10;, score=31.404 total time=   3.8s
# [CV 3/5; 2/4] START estimator__C=10.............................................
# [CV 3/5; 2/4] END .............estimator__C=10;, score=31.656 total time=   3.8s
# [CV 4/5; 2/4] START estimator__C=10.............................................
# [CV 4/5; 2/4] END .............estimator__C=10;, score=34.539 total time=   3.8s
# [CV 5/5; 2/4] START estimator__C=10.............................................
# [CV 5/5; 2/4] END .............estimator__C=10;, score=34.877 total time=   4.0s
# [CV 1/5; 3/4] START estimator__C=100............................................
# [CV 1/5; 3/4] END ............estimator__C=100;, score=29.095 total time=   7.1s
# [CV 2/5; 3/4] START estimator__C=100............................................
# [CV 2/5; 3/4] END ............estimator__C=100;, score=28.874 total time=   7.1s
# [CV 3/5; 3/4] START estimator__C=100............................................
# [CV 3/5; 3/4] END ............estimator__C=100;, score=27.495 total time=   6.8s
# [CV 4/5; 3/4] START estimator__C=100............................................
# [CV 4/5; 3/4] END ............estimator__C=100;, score=32.303 total time=   7.0s
# [CV 5/5; 3/4] START estimator__C=100............................................
# [CV 5/5; 3/4] END ............estimator__C=100;, score=30.940 total time=   7.0s
# [CV 1/5; 4/4] START estimator__C=1000...........................................
# [CV 1/5; 4/4] END ...........estimator__C=1000;, score=27.700 total time=   7.2s
# [CV 2/5; 4/4] START estimator__C=1000...........................................
# [CV 2/5; 4/4] END ...........estimator__C=1000;, score=27.043 total time=   7.1s
# [CV 3/5; 4/4] START estimator__C=1000...........................................
# [CV 3/5; 4/4] END ...........estimator__C=1000;, score=26.098 total time=   6.9s
# [CV 4/5; 4/4] START estimator__C=1000...........................................
# [CV 4/5; 4/4] END ...........estimator__C=1000;, score=30.234 total time=   7.1s
# [CV 5/5; 4/4] START estimator__C=1000...........................................
# [CV 5/5; 4/4] END ...........estimator__C=1000;, score=29.607 total time=   7.4s
# GridSearchCV(cv=5, estimator=OneVsRestClassifier(estimator=LinearSVC()),
#              param_grid={'estimator__C': [1, 10, 100, 1000]},
#              scoring=make_scorer(avg_jacard), verbose=10)

# %%
CV_svc.best_params_
# Out:
# {'estimator__C': 10}

# %%
best_model = CV_svc.best_estimator_

# %%
y_pred = best_model.predict(X_test)

print_score(y_pred, best_model)
# Out:
# Clf:  OneVsRestClassifier
# Jacard score: 34.97036645835167
# Hamming loss: 2.33086876155268
# ---

# %% [markdown]
# Confusion matrix

# %%
for i in range(y_train.shape[1]):
    print(multilabel_binarizer.classes_[i])
    print(confusion_matrix(y_test[:,i], y_pred[:,i]))
    print("")
# Out:
# ajax
# [[533   1]
#  [  7   0]]
#
# algorithm
# [[527   6]
#  [  4   4]]
#
# amazon
# [[534   0]
#  [  2   5]]
#
# android
# [[485   7]
#  [ 12  37]]
#
# angular
# [[536   1]
#  [  3   1]]
#
# apache
# [[536   1]
#  [  4   0]]
#
# api
# [[529   2]
#  [  5   5]]
#
# array
# [[526   3]
#  [  6   6]]
#
# asp
# [[504   9]
#  [ 11  17]]
#
# authentication
# [[530   1]
#  [  7   3]]
#
# bash
# [[531   2]
#  [  5   3]]
#
# build
# [[534   1]
#  [  5   1]]
#
# c
# [[390  34]
#  [ 57  60]]
#
# chrome
# [[536   1]
#  [  3   1]]
#
# class
# [[536   0]
#  [  4   1]]
#
# cocoa
# [[522   7]
#  [ 12   0]]
#
# code
# [[530   4]
#  [  7   0]]
#
# command
# [[534   1]
#  [  5   1]]
#
# core
# [[524   4]
#  [ 10   3]]
#
# cs
# [[526   3]
#  [  5   7]]
#
# data
# [[521   7]
#  [  6   7]]
#
# database
# [[522  10]
#  [  7   2]]
#
# dataframe
# [[533   2]
#  [  3   3]]
#
# design
# [[534   5]
#  [  2   0]]
#
# django
# [[532   2]
#  [  2   5]]
#
# eclipse
# [[537   0]
#  [  3   1]]
#
# entity
# [[532   1]
#  [  5   3]]
#
# event
# [[537   0]
#  [  4   0]]
#
# facebook
# [[535   1]
#  [  3   2]]
#
# file
# [[527   3]
#  [  9   2]]
#
# framework
# [[522   9]
#  [  7   3]]
#
# function
# [[531   2]
#  [  7   1]]
#
# git
# [[528   0]
#  [  7   6]]
#
# google
# [[531   2]
#  [  5   3]]
#
# gradle
# [[534   0]
#  [  5   2]]
#
# hibernate
# [[533   4]
#  [  2   2]]
#
# html
# [[509   7]
#  [ 14  11]]
#
# http
# [[523   7]
#  [  6   5]]
#
# image
# [[529   4]
#  [  5   3]]
#
# interface
# [[533   1]
#  [  4   3]]
#
# io
# [[460  15]
#  [ 31  35]]
#
# iphone
# [[493  16]
#  [ 24   8]]
#
# j
# [[522   7]
#  [  7   5]]
#
# java
# [[452  24]
#  [ 33  32]]
#
# javascript
# [[478  11]
#  [ 26  26]]
#
# jpa
# [[533   3]
#  [  4   1]]
#
# jquery
# [[517   3]
#  [  8  13]]
#
# json
# [[533   3]
#  [  4   1]]
#
# laravel
# [[537   0]
#  [  3   1]]
#
# layout
# [[532   2]
#  [  5   2]]
#
# learning
# [[532   5]
#  [  4   0]]
#
# library
# [[535   1]
#  [  5   0]]
#
# line
# [[531   0]
#  [ 10   0]]
#
# linux
# [[522   8]
#  [  7   4]]
#
# macos
# [[536   0]
#  [  3   2]]
#
# maven
# [[534   1]
#  [  5   1]]
#
# memory
# [[533   3]
#  [  3   2]]
#
# mongodb
# [[532   1]
#  [  6   2]]
#
# multithreading
# [[523   4]
#  [  8   6]]
#
# mvc
# [[509  12]
#  [ 11   9]]
#
# mysql
# [[526   2]
#  [ 11   2]]
#
# net
# [[466  19]
#  [ 23  33]]
#
# node
# [[530   2]
#  [  3   6]]
#
# numpy
# [[529   3]
#  [  3   6]]
#
# objective
# [[500  12]
#  [ 25   4]]
#
# optimization
# [[527   3]
#  [ 10   1]]
#
# panda
# [[529   3]
#  [  3   6]]
#
# performance
# [[526   6]
#  [  6   3]]
#
# php
# [[519   6]
#  [  8   8]]
#
# postgresql
# [[533   2]
#  [  6   0]]
#
# processing
# [[531   3]
#  [  5   2]]
#
# python
# [[456  15]
#  [ 25  45]]
#
# r
# [[525   7]
#  [  7   2]]
#
# rail
# [[527   1]
#  [  6   7]]
#
# reactjs
# [[538   0]
#  [  2   1]]
#
# rest
# [[535   1]
#  [  4   1]]
#
# ruby
# [[525   2]
#  [  8   6]]
#
# security
# [[526  10]
#  [  5   0]]
#
# selenium
# [[536   0]
#  [  5   0]]
#
# server
# [[525   4]
#  [  6   6]]
#
# service
# [[524   6]
#  [  5   6]]
#
# shell
# [[534   1]
#  [  6   0]]
#
# spark
# [[537   2]
#  [  1   1]]
#
# spring
# [[519   1]
#  [  9  12]]
#
# sql
# [[510   8]
#  [ 12  11]]
#
# string
# [[525   5]
#  [  6   5]]
#
# studio
# [[521   2]
#  [  9   9]]
#
# swift
# [[520   4]
#  [  9   8]]
#
# testing
# [[536   0]
#  [  3   2]]
#
# touch
# [[527   3]
#  [ 11   0]]
#
# type
# [[531   5]
#  [  5   0]]
#
# ubuntu
# [[536   1]
#  [  4   0]]
#
# video
# [[535   2]
#  [  2   2]]
#
# visual
# [[525   4]
#  [  5   7]]
#
# web
# [[510  12]
#  [ 11   8]]
#
# window
# [[519   5]
#  [ 12   5]]
#
# wpf
# [[529   2]
#  [  7   3]]
#
# x
# [[518   6]
#  [ 16   1]]
#
# xcode
# [[516   8]
#  [ 13   4]]
#
# xml
# [[536   0]
#  [  5   0]]

# %% [markdown]
# Exctracting feature importance

# %%
def print_top10(feature_names, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("--------------------------------------------")
        print("%s: %s" % (class_label,
              " ".join(feature_names[j] for j in top10)))
        print("--------------------------------------------")

# %%
feature_names = vectorizer_X.get_feature_names()

# %%
print_top10(feature_names, best_model, multilabel_binarizer.classes_)
# Out:
# --------------------------------------------
# ajax: boot context 21 codep code device browser development 200 compile
# --------------------------------------------
# --------------------------------------------
# algorithm: aspnet book bite 124 coordinate address 25 drop apps binary
# --------------------------------------------
# --------------------------------------------
# amazon: draw -- -1 deploy 01 child believe cpu basically eg
# --------------------------------------------
# --------------------------------------------
# android: dependency accord come configure date anyone -1 00 05 -i
# --------------------------------------------
# --------------------------------------------
# angular: application documentation constructor docker background dynamic const development amp codelt
# --------------------------------------------
# --------------------------------------------
# apache: ask article controller 00 center base description big completely create
# --------------------------------------------
# --------------------------------------------
# api: 1000 alt branch class ap 124 11 directly collection default
# --------------------------------------------
# --------------------------------------------
# array: api create eax current cout 29 apple 05 detail 11
# --------------------------------------------
# --------------------------------------------
# asp: avoid android cause cookie answer application 200 36 09-11 already
# --------------------------------------------
# --------------------------------------------
# authentication: believe 16 01 1000 duplicate choose appreciatedp access database another
# --------------------------------------------
# --------------------------------------------
# bash: 00 command could avoid 26 convert compute close appreciatedp determine
# --------------------------------------------
# --------------------------------------------
# build: compare activity avoid django appreciate advantage duplicate date docker 00
# --------------------------------------------
# --------------------------------------------
# c: character edit applications 22 different animation 1000 400 authority 10
# --------------------------------------------
# --------------------------------------------
# chrome: article convert easy documentation correct click behavior aware cout center
# --------------------------------------------
# --------------------------------------------
# class: apply drop amp cookie catch byte asm 26 differences difference
# --------------------------------------------
# --------------------------------------------
# cocoa: complete certificate 45 advantage -o basically computer close appear efficient
# --------------------------------------------
# --------------------------------------------
# code: common eclipse args dataframe always appreciate css context 09-11 active
# --------------------------------------------
# --------------------------------------------
# command: 400 14 begin along 9935 author -o 25 -gt actually
# --------------------------------------------
# --------------------------------------------
# core: app cookie dynamic dev close accept 09-11 alt better certificate
# --------------------------------------------
# --------------------------------------------
# cs: determine deal appear ask char aws echo chargt eandroidruntime -1
# --------------------------------------------
# --------------------------------------------
# data: app anyone commit cookie cout case bundle bottom easy component
# --------------------------------------------
# --------------------------------------------
# database: 17 difference child create container contact color df 01 12
# --------------------------------------------
# --------------------------------------------
# dataframe: basic build book 9935 32 catch df --- account 14
# --------------------------------------------
# --------------------------------------------
# design: contain 36 complete detail chrome better device convert determine connection
# --------------------------------------------
# --------------------------------------------
# django: android algorithm basically appear cannot bug 11 basic annotation character
# --------------------------------------------
# --------------------------------------------
# eclipse: 45 arguments check alt automatically actually around appreciatedp configuration div
# --------------------------------------------
# --------------------------------------------
# entity: binary catch also case compile df bar 52 access 01
# --------------------------------------------
# --------------------------------------------
# event: come character array bottom boot bind apply comment condition browser
# --------------------------------------------
# --------------------------------------------
# facebook: applications artifactidgt break client aware device canvas better display args
# --------------------------------------------
# --------------------------------------------
# file: differences docker -o configuration 21 byte consolelog -gt arguments author
# --------------------------------------------
# --------------------------------------------
# framework: distance bug certain amp basically case codelt date access efficient
# --------------------------------------------
# --------------------------------------------
# function: apple android authentication dynamic --- def -o current actually 05
# --------------------------------------------
# --------------------------------------------
# git: anyone 32 cookie -1 algorithm core along ajax convert actually
# --------------------------------------------
# --------------------------------------------
# google: browser apps easy elements currently advantage attempt convert center dynamic
# --------------------------------------------
# --------------------------------------------
# gradle: container 00 document cookie directly boolean actually core -- account
# --------------------------------------------
# --------------------------------------------
# hibernate: control complete achieve anyone advance 9935 change add eax break
# --------------------------------------------
# --------------------------------------------
# html: author api comment anything 25 due -1 14 db controller
# --------------------------------------------
# --------------------------------------------
# http: codep 11 09-11 completely boot debug df dev 124 bite
# --------------------------------------------
# --------------------------------------------
# image: achieve 26 byte advance deal aware article async 11 -o
# --------------------------------------------
# --------------------------------------------
# interface: click better access const decide certain catch come detect component
# --------------------------------------------
# --------------------------------------------
# io: appear eg element could 09-11 13 -o break accept -i
# --------------------------------------------
# --------------------------------------------
# iphone: dependencies click app close dependency build 13 -o eg eclipse
# --------------------------------------------
# --------------------------------------------
# j: control contain 09-11 commit data db 31 annotation begin copy
# --------------------------------------------
# --------------------------------------------
# java: dynamic 29 12 bottom 11 content access block 9935 able
# --------------------------------------------
# --------------------------------------------
# javascript: 05 15 available 09-11 break dependencies behavior address 2019-12-06t00 deploy
# --------------------------------------------
# --------------------------------------------
# jpa: documentation algorithm consolelog change control def 45 args account eax
# --------------------------------------------
# --------------------------------------------
# jquery: compile application dependency 05 25 09-11 code background disable break
# --------------------------------------------
# --------------------------------------------
# json: assembly const connect 00 different become arguments 2019-12-06t00 ajax annotation
# --------------------------------------------
# --------------------------------------------
# laravel: ap cannot 11 auth declare -- check code 21 17
# --------------------------------------------
# --------------------------------------------
# layout: blockquote character always 29 browser 23 achieve 25 chrome -1
# --------------------------------------------
# --------------------------------------------
# learning: depend 45 40 22 auth choose approach address 12 background
# --------------------------------------------
# --------------------------------------------
# library: authority asm deal change available build condition eax check always
# --------------------------------------------
# --------------------------------------------
# line: attempt appreciate either animation -o configuration along 25 31 -gt
# --------------------------------------------
# --------------------------------------------
# linux: binary eax cpu close device avoid compiler color -gt class
# --------------------------------------------
# --------------------------------------------
# macos: color differences -gt alt asm along bool deal 45 big
# --------------------------------------------
# --------------------------------------------
# maven: 10 45 directory 2019-12-06t00 actually due either download -gt 30
# --------------------------------------------
# --------------------------------------------
# memory: echo ask allow advance cause class available ap 13 52
# --------------------------------------------
# --------------------------------------------
# mongodb: device 15 array catch around 50 check description debug copy
# --------------------------------------------
# --------------------------------------------
# multithreading: 35 cpu currently api element 14 buffer 17 124 10
# --------------------------------------------
# --------------------------------------------
# mvc: -- describe deal activity application 200 20 codelt base across
# --------------------------------------------
# --------------------------------------------
# mysql: appear branch docker available blockquote alloc 13 apple 17 anything
# --------------------------------------------
# --------------------------------------------
# net: 57342 android address due 14 command application always 09-11 200
# --------------------------------------------
# --------------------------------------------
# node: box address br 31 dev 09-11 commit edge control copy
# --------------------------------------------
# --------------------------------------------
# numpy: array document alloc either eax 05 -o command 11 copy
# --------------------------------------------
# --------------------------------------------
# objective: cookie eg develop 13 aws build debug crash close -o
# --------------------------------------------
# --------------------------------------------
# optimization: eg 15 calculate certificate condition book eaxquot dataframe apply collection
# --------------------------------------------
# --------------------------------------------
# panda: 9935 catch compute -o char add const achieve 100 accord
# --------------------------------------------
# --------------------------------------------
# performance: assembly different 13 25 deploy eax apps call application achieve
# --------------------------------------------
# --------------------------------------------
# php: cod eandroidruntime draw 17 40 catch auth css eaxquot attribute
# --------------------------------------------
# --------------------------------------------
# postgresql: drop arguments applications 45 aspnet allow 100 detect compiler app
# --------------------------------------------
# --------------------------------------------
# processing: client bean column -o codelt 10 copy dependencies 12 core
# --------------------------------------------
# --------------------------------------------
# python: 21 element answer 11 best could -o 124 100 16
# --------------------------------------------
# --------------------------------------------
# r: common def background determine -o bug create cannot 12 dynamic
# --------------------------------------------
# --------------------------------------------
# rail: app attempt contain boolean bottom avoid begin consolelog compute ap
# --------------------------------------------
# --------------------------------------------
# reactjs: arguments 21 complete audio 22 200 01 buffer 14 click
# --------------------------------------------
# --------------------------------------------
# rest: class anything disable best description drop crash assembly docker asm
# --------------------------------------------
# --------------------------------------------
# ruby: attribute better app eg always avoid compute bottom codepre ap
# --------------------------------------------
# --------------------------------------------
# security: cell deal active 16 either 17 11 core correctly declare
# --------------------------------------------
# --------------------------------------------
# selenium: component database br codelt configure become add configuration anything 124
# --------------------------------------------
# --------------------------------------------
# server: echo 17 100 define 12 01 cookie br def await
# --------------------------------------------
# --------------------------------------------
# service: compile char differences boot basically detail delete aware anything develop
# --------------------------------------------
# --------------------------------------------
# shell: boolean 00 current 100 eax cout -gt css child eaxquot
# --------------------------------------------
# --------------------------------------------
# spark: best base completely cell document appear api accord 00 display
# --------------------------------------------
# --------------------------------------------
# spring: draw account animate anyone asm alloc able args db across
# --------------------------------------------
# --------------------------------------------
# sql: 13 document cell constructor 20 100 17 center cod 12
# --------------------------------------------
# --------------------------------------------
# string: -o author description allow code accept development account 100 57342
# --------------------------------------------
# --------------------------------------------
# studio: -1 directly artifactidgt 14 behavior elements appreciatedp 100 certificate 36
# --------------------------------------------
# --------------------------------------------
# swift: center declare docker contact chargt back build database avoid -i
# --------------------------------------------
# --------------------------------------------
# testing: config common core 50 debug author compiler console code eax
# --------------------------------------------
# --------------------------------------------
# touch: 45 container available bean certain -o drop 01 efficient appear
# --------------------------------------------
# --------------------------------------------
# type: cause documentation double 22 another annotation 200 50 configuration 36
# --------------------------------------------
# --------------------------------------------
# ubuntu: compute cause bundle ajax close -gt 100 connect auth await
# --------------------------------------------
# --------------------------------------------
# video: 124 config active 15 -1 click eandroidruntime compile cell 23
# --------------------------------------------
# --------------------------------------------
# visual: 09-11 appreciatedp eaxquot blockquote dynamic base certificate appreciate configure 36
# --------------------------------------------
# --------------------------------------------
# web: build detail aware dependencies 09-11 anything dependency create char columns
# --------------------------------------------
# --------------------------------------------
# window: assembly accord 17 codep api coordinate basic boolean aware amp
# --------------------------------------------
# --------------------------------------------
# wpf: add available case database cause default around activity become 200
# --------------------------------------------
# --------------------------------------------
# x: along achieve add aware delete 13 could consider 100 124
# --------------------------------------------
# --------------------------------------------
# xcode: cannot -i 09-11 collection authority big compiler copy automatically dependencies
# --------------------------------------------
# --------------------------------------------
# xml: coordinate context dynamic 50 component duplicate css char document eclipse
# --------------------------------------------

# %% [markdown]
# # TensorFlow (Keras)

# %% [markdown]
# #  keras pad_sequence and Tokenizer
# ````
# ?tf.keras.preprocessing.text.Tokenizer
# ?tf.keras.utils.pad_sequences
#
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/pad_sequences
# `````

# %% [markdown]
# This function transforms a list (of length num_samples) of sequences (lists of integers) into a 2D Numpy array of shape (num_samples, num_timesteps). num_timesteps is either the maxlen argument if provided, or the length of the longest sequence in the list.
#
# Sequences that are shorter than num_timesteps are padded with value until they are num_timesteps long.
#
# Sequences longer than num_timesteps are truncated so that they fit the desired length.
#
# The position where padding or truncation happens is determined by the arguments padding and truncating, respectively. Pre-padding or removing values from the beginning of the sequence is the default.

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

### Let's create some mock data
def get_mock_up_data():

    X = df1['full_review']
    y = df1['Tags'] 

    ### Let's tokenize the vocabulary 
    tk = Tokenizer()
    tk.fit_on_texts(X)
    vocab_size = len(tk.word_index)
    print(f'There are {vocab_size} different words in your corpus')
    X_token = tk.texts_to_sequences(X)

    ### Pad the inputs
    X_pad = pad_sequences(X_token, dtype='float32', padding='post')
    
    return X_pad, y, vocab_size

X_pad, y, vocab_size = get_mock_up_data()
print("X_pad.shape", X_pad.shape)
X_pad
# Out:
# There are 48121 different words in your corpus
# X_pad.shape (2704, 2784)
# array([[1.7420e+03, 5.5360e+03, 2.8200e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.0100e+02, 1.9300e+02, 2.0100e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [2.4300e+02, 8.3620e+03, 3.0800e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        ...,
#        [2.7000e+01, 4.8069e+04, 3.3570e+03, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [2.5000e+02, 1.9147e+04, 1.9148e+04, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [3.6500e+03, 4.1500e+02, 5.7900e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00]], dtype=float32)

# %%
# 80/20 split
X_train, X_test, y_train, y_test = train_test_split(X_pad, y_bin, test_size = 0.2, random_state = 0)

# %%
def avg_jacard(y_true,y_pred):
    jacard = np.minimum(y_true,y_pred).sum(axis=1) / np.maximum(y_true,y_pred).sum(axis=1)    
    return jacard.mean()*100
    
def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    print("Jacard score: {}".format(avg_jacard(y_test, y_pred)))
    print("Hamming loss: {}".format(hamming_loss(y_pred, y_test)*100))
    print("---")

# %%
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.svm import LinearSVC
dummy = DummyClassifier()
sgd = SGDClassifier()
lr = LogisticRegression()
mn = MultinomialNB()
svc = LinearSVC()
perceptron = Perceptron()
pac = PassiveAggressiveClassifier()

for classifier in [dummy, sgd, lr, mn, svc, perceptron, pac]:
    clf = OneVsRestClassifier(classifier)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print_score(y_pred, classifier)
# Out:
# Clf:  DummyClassifier
# Jacard score: 0.0
# Hamming loss: 2.589648798521257
# ---
# Clf:  SGDClassifier
# Jacard score: 3.5419211072956855
# Hamming loss: 6.077634011090573
# ---
# Clf:  LogisticRegression
# Jacard score: 1.9947734510907282
# Hamming loss: 6.33086876155268
# ---
# Clf:  MultinomialNB
# Jacard score: 3.6011957164252593
# Hamming loss: 33.284658040665434
# ---
# Clf:  LinearSVC
# Jacard score: 3.7187460315705705
# Hamming loss: 10.606284658040666
# ---
# Clf:  Perceptron
# Jacard score: 3.4581818607859707
# Hamming loss: 5.628465804066543
# ---
# Clf:  PassiveAggressiveClassifier
# Jacard score: 3.776787757549442
# Hamming loss: 6.846580406654344
# ---

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier()
mlpc.fit(X_train, y_train)

y_pred = mlpc.predict(X_test)

print_score(y_pred, mlpc)
# Out:
# Clf:  MLPClassifier
# Jacard score: 0.3710993856266439
# Hamming loss: 8.863216266173753
# ---

# %% [markdown]
#  # Word2Vec

# %% [markdown]
# Word2vec: Implementation with Gensim¶
#
# Robust implementation is not easy.
#
# The gensim package is the reference if you want to embed your words using word2vec.

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Let's convert the list of sentences to a list of lists of words with a Keras utility function

from tensorflow.keras.preprocessing.text import text_to_word_sequence
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import metrics as kmetrics
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
import gensim

# %%
## Création du modèle Word2Vec

# %%
w2v_size = 300
w2v_window = 5
w2v_min_count = 1
w2v_epochs = 10
maxlen = 24  # adapt to length of sentences
sentences = df1['full_review'].to_list()
sentences = [gensim.utils.simple_preprocess(text) for text in sentences]

# %%
#sentences[0]

# %%
#pip install --upgrade gensim --user

# %%
# Création et entraînement du modèle Word2Vec

print("Build & train Word2Vec model ...")
w2v_model = gensim.models.Word2Vec(min_count=w2v_min_count,
                                   window=w2v_window,
                                   vector_size=w2v_size,
                                   seed=42,
                                   workers=1)
#                                                workers=multiprocessing.cpu_count())
w2v_model.build_vocab(sentences)
w2v_model.train(sentences,
                total_examples=w2v_model.corpus_count,
                epochs=w2v_epochs)
model_vectors = w2v_model.wv
w2v_words = model_vectors.index_to_key
print("Vocabulary size: %i" % len(w2v_words))
print("Word2Vec trained")
# Out:
# Build & train Word2Vec model ...
# Vocabulary size: 32190
# Word2Vec trained

# %%
#import gensim
#print(gensim.__version__)

# %%
# Préparation des sentences (tokenization)

print("Fit Tokenizer ...")
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
x_sentences = pad_sequences(tokenizer.texts_to_sequences(sentences),
                            maxlen=maxlen,
                            padding='post')

num_words = len(tokenizer.word_index) + 1
print("Number of unique words: %i" % num_words)
# Out:
# Fit Tokenizer ...
# Number of unique words: 32191

# %%
## Création de la matrice d'embedding

# %%
# Création de la matrice d'embedding

print("Create Embedding matrix ...")
w2v_size = 300
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1
embedding_matrix = np.zeros((vocab_size, w2v_size))
i = 0
j = 0

for word, idx in word_index.items():
    i += 1
    if word in w2v_words:
        j += 1
        embedding_vector = model_vectors[word]
        if embedding_vector is not None:
            embedding_matrix[idx] = model_vectors[word]

word_rate = np.round(j / i, 4)
print("Word embedding rate : ", word_rate)
print("Embedding matrix: %s" % str(embedding_matrix.shape))
# Out:
# Create Embedding matrix ...
# Word embedding rate :  1.0
# Embedding matrix: (32191, 300)

# %%
## Création du modèle d'embedding

# %%
# Création du modèle

input = Input(shape=(len(x_sentences), maxlen), dtype='float64')
word_input = Input(shape=(maxlen, ), dtype='float64')
word_embedding = Embedding(input_dim=vocab_size,
                           output_dim=w2v_size,
                           weights=[embedding_matrix],
                           input_length=maxlen)(word_input)
word_vec = GlobalAveragePooling1D()(word_embedding)
embed_model = Model([word_input], word_vec)

embed_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 24)]              0
#
#  embedding (Embedding)       (None, 24, 300)           9657300
#
#  global_average_pooling1d (G  (None, 300)              0
#  lobalAveragePooling1D)
#
# =================================================================
# Total params: 9,657,300
# Trainable params: 9,657,300
# Non-trainable params: 0
# _________________________________________________________________

# %%
embeddings = embed_model.predict(x_sentences)
embeddings.shape
# Out:
# 85/85 [==============================] - 0s 1ms/step
# (2704, 300)

# %%
#X = df1['full_review']
y = df1['Tags']

# %%
x_sentences.shape
# Out:
# (2704, 24)

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %%
y_bin.shape
# Out:
# (2704, 100)

# %% [markdown]
# # PCA

# %%
clf = TruncatedSVD(20)
Xpca = clf.fit_transform(x_sentences)

# %%
clf.explained_variance_ratio_
# Out:
# array([0.0855222 , 0.0749807 , 0.05716565, 0.0481494 , 0.04685347,
#        0.04460409, 0.04423636, 0.04341329, 0.04135118, 0.04011002,
#        0.03992666, 0.0386398 , 0.03748742, 0.03659947, 0.03610279,
#        0.03563562, 0.03378032, 0.03337349, 0.0329429 , 0.03166538])

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, 21), clf.explained_variance_ratio_.cumsum(),marker = "o", linestyle = "--")
plt.title("Explained Variance by Componants")
plt.xlabel("Nomber of componants")
plt.ylabel("Explained Variance")
# Out:
# Text(0, 0.5, 'Explained Variance')

# %%
clf = TruncatedSVD(15)
Xpca_word2vec = clf.fit_transform(x_sentences)

# %%
# 80/20 split
X_train, X_test, y_train, y_test = train_test_split(Xpca_word2vec, y_bin, test_size = 0.2, random_state = 0)

# %%
def avg_jacard(y_true,y_pred):
    jacard = np.minimum(y_true,y_pred).sum(axis=1) / np.maximum(y_true,y_pred).sum(axis=1)    
    return jacard.mean()*100
    
def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    print("Jacard score: {}".format(avg_jacard(y_test, y_pred)))
    print("Hamming loss: {}".format(hamming_loss(y_pred, y_test)*100))
    print("---")

# %%
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.svm import LinearSVC
dummy = DummyClassifier()
sgd = SGDClassifier()
lr = LogisticRegression()
svc = LinearSVC()
perceptron = Perceptron()
pac = PassiveAggressiveClassifier()

for classifier in [dummy, sgd, lr, svc, perceptron, pac]:
    clf = OneVsRestClassifier(classifier)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print_score(y_pred, classifier)
# Out:
# Clf:  DummyClassifier
# Jacard score: 0.0
# Hamming loss: 2.589648798521257
# ---
# Clf:  SGDClassifier
# Jacard score: 2.5041076196344214
# Hamming loss: 4.401109057301293
# ---
# Clf:  LogisticRegression
# Jacard score: 0.0
# Hamming loss: 2.598890942698706
# ---
# Clf:  LinearSVC
# Jacard score: 4.381923195898577
# Hamming loss: 9.384473197781885
# ---
# Clf:  Perceptron
# Jacard score: 4.19708361781864
# Hamming loss: 4.66358595194085
# ---
# Clf:  PassiveAggressiveClassifier
# Jacard score: 4.452597874501756
# Hamming loss: 5.859519408502773
# ---

# %%
SGDClassifier
# Out:
# sklearn.linear_model._stochastic_gradient.SGDClassifier

# %%
sgd = SGDClassifier()
clf = OneVsRestClassifier(sgd)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, sgd)
# Out:
# Clf:  SGDClassifier
# Jacard score: 3.103763994815425
# Hamming loss: 3.99445471349353
# ---

# %%
OneVsRestClassifier
# Out:
# sklearn.multiclass.OneVsRestClassifier

# %%
lr = LogisticRegression()

clf = OneVsRestClassifier(lr)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, lr)
# Out:
# Clf:  LogisticRegression
# Jacard score: 0.0
# Hamming loss: 2.598890942698706
# ---

# %%
RandomForestClassifier
# Out:
# sklearn.ensemble._forest.RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

print_score(y_pred, rfc)
# Out:
# Clf:  RandomForestClassifier
# Jacard score: 0.0
# Hamming loss: 2.589648798521257
# ---

# %% [markdown]
# MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier()
mlpc.fit(X_train, y_train)

y_pred = mlpc.predict(X_test)

print_score(y_pred, mlpc)
# Out:
# Clf:  MLPClassifier
# Jacard score: 3.4958130799165916
# Hamming loss: 4.918669131238447
# ---

# %%
param_grid = {'estimator__C':[1,10,100,1000]
              }

# %%
svc = OneVsRestClassifier(LinearSVC())
CV_svc = model_selection.GridSearchCV(estimator=svc, param_grid=param_grid, cv= 5, verbose=10, 
                                      scoring=make_scorer(avg_jacard,greater_is_better=True))
CV_svc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START estimator__C=1..............................................
# [CV 1/5; 1/4] END ...............estimator__C=1;, score=2.748 total time=   1.6s
# [CV 2/5; 1/4] START estimator__C=1..............................................
# [CV 2/5; 1/4] END ...............estimator__C=1;, score=3.569 total time=   1.6s
# [CV 3/5; 1/4] START estimator__C=1..............................................
# [CV 3/5; 1/4] END ...............estimator__C=1;, score=2.020 total time=   1.5s
# [CV 4/5; 1/4] START estimator__C=1..............................................
# [CV 4/5; 1/4] END ...............estimator__C=1;, score=3.889 total time=   1.6s
# [CV 5/5; 1/4] START estimator__C=1..............................................
# [CV 5/5; 1/4] END ...............estimator__C=1;, score=4.020 total time=   1.6s
# [CV 1/5; 2/4] START estimator__C=10.............................................
# [CV 1/5; 2/4] END ..............estimator__C=10;, score=3.795 total time=   1.6s
# [CV 2/5; 2/4] START estimator__C=10.............................................
# [CV 2/5; 2/4] END ..............estimator__C=10;, score=2.915 total time=   1.6s
# [CV 3/5; 2/4] START estimator__C=10.............................................
# [CV 3/5; 2/4] END ..............estimator__C=10;, score=3.687 total time=   1.5s
# [CV 4/5; 2/4] START estimator__C=10.............................................
# [CV 4/5; 2/4] END ..............estimator__C=10;, score=3.021 total time=   1.6s
# [CV 5/5; 2/4] START estimator__C=10.............................................
# [CV 5/5; 2/4] END ..............estimator__C=10;, score=3.600 total time=   1.6s
# [CV 1/5; 3/4] START estimator__C=100............................................
# [CV 1/5; 3/4] END .............estimator__C=100;, score=4.868 total time=   1.6s
# [CV 2/5; 3/4] START estimator__C=100............................................
# [CV 2/5; 3/4] END .............estimator__C=100;, score=3.814 total time=   1.6s
# [CV 3/5; 3/4] START estimator__C=100............................................
# [CV 3/5; 3/4] END .............estimator__C=100;, score=3.278 total time=   1.5s
# [CV 4/5; 3/4] START estimator__C=100............................................
# [CV 4/5; 3/4] END .............estimator__C=100;, score=4.763 total time=   1.6s
# [CV 5/5; 3/4] START estimator__C=100............................................
# [CV 5/5; 3/4] END .............estimator__C=100;, score=2.276 total time=   1.6s
# [CV 1/5; 4/4] START estimator__C=1000...........................................
# [CV 1/5; 4/4] END ............estimator__C=1000;, score=2.388 total time=   1.6s
# [CV 2/5; 4/4] START estimator__C=1000...........................................
# [CV 2/5; 4/4] END ............estimator__C=1000;, score=3.430 total time=   1.6s
# [CV 3/5; 4/4] START estimator__C=1000...........................................
# [CV 3/5; 4/4] END ............estimator__C=1000;, score=2.941 total time=   1.5s
# [CV 4/5; 4/4] START estimator__C=1000...........................................
# [CV 4/5; 4/4] END ............estimator__C=1000;, score=3.798 total time=   1.6s
# [CV 5/5; 4/4] START estimator__C=1000...........................................
# [CV 5/5; 4/4] END ............estimator__C=1000;, score=3.049 total time=   1.7s
# GridSearchCV(cv=5, estimator=OneVsRestClassifier(estimator=LinearSVC()),
#              param_grid={'estimator__C': [1, 10, 100, 1000]},
#              scoring=make_scorer(avg_jacard), verbose=10)

# %%
CV_svc.best_params_
# Out:
# {'estimator__C': 100}

# %%
best_model = CV_svc.best_estimator_

# %%
y_pred = best_model.predict(X_test)

print_score(y_pred, best_model)
# Out:
# Clf:  OneVsRestClassifier
# Jacard score: 5.0575164826497865
# Hamming loss: 9.391866913123845
# ---

# %% [markdown]
# Confusion matrix

# %%
for i in range(y_train.shape[1]):
    print(multilabel_binarizer.classes_[i])
    print(confusion_matrix(y_test[:,i], y_pred[:,i]))
    print("")
# Out:
# ajax
# [[533   1]
#  [  7   0]]
#
# algorithm
# [[474  59]
#  [  8   0]]
#
# amazon
# [[504  30]
#  [  7   0]]
#
# android
# [[382 110]
#  [ 33  16]]
#
# angular
# [[519  18]
#  [  4   0]]
#
# apache
# [[537   0]
#  [  4   0]]
#
# api
# [[503  28]
#  [  9   1]]
#
# array
# [[509  20]
#  [ 10   2]]
#
# asp
# [[497  16]
#  [ 27   1]]
#
# authentication
# [[530   1]
#  [ 10   0]]
#
# bash
# [[500  33]
#  [  8   0]]
#
# build
# [[526   9]
#  [  6   0]]
#
# c
# [[124 300]
#  [ 37  80]]
#
# chrome
# [[531   6]
#  [  4   0]]
#
# class
# [[502  34]
#  [  5   0]]
#
# cocoa
# [[513  16]
#  [ 12   0]]
#
# code
# [[489  45]
#  [  5   2]]
#
# command
# [[466  69]
#  [  6   0]]
#
# core
# [[510  18]
#  [ 12   1]]
#
# cs
# [[517  12]
#  [ 11   1]]
#
# data
# [[511  17]
#  [ 11   2]]
#
# database
# [[485  47]
#  [  6   3]]
#
# dataframe
# [[449  86]
#  [  4   2]]
#
# design
# [[514  25]
#  [  2   0]]
#
# django
# [[514  20]
#  [  6   1]]
#
# eclipse
# [[512  25]
#  [  3   1]]
#
# entity
# [[506  27]
#  [  7   1]]
#
# event
# [[507  30]
#  [  4   0]]
#
# facebook
# [[505  31]
#  [  5   0]]
#
# file
# [[504  26]
#  [ 11   0]]
#
# framework
# [[497  34]
#  [ 10   0]]
#
# function
# [[523  10]
#  [  8   0]]
#
# git
# [[515  13]
#  [ 13   0]]
#
# google
# [[527   6]
#  [  8   0]]
#
# gradle
# [[522  12]
#  [  7   0]]
#
# hibernate
# [[502  35]
#  [  3   1]]
#
# html
# [[474  42]
#  [ 19   6]]
#
# http
# [[529   1]
#  [ 11   0]]
#
# image
# [[498  35]
#  [  8   0]]
#
# interface
# [[473  61]
#  [  5   2]]
#
# io
# [[256 219]
#  [ 40  26]]
#
# iphone
# [[475  34]
#  [ 30   2]]
#
# j
# [[313 216]
#  [  8   4]]
#
# java
# [[335 141]
#  [ 43  22]]
#
# javascript
# [[473  16]
#  [ 48   4]]
#
# jpa
# [[535   1]
#  [  5   0]]
#
# jquery
# [[442  78]
#  [ 19   2]]
#
# json
# [[536   0]
#  [  5   0]]
#
# laravel
# [[494  43]
#  [  3   1]]
#
# layout
# [[518  16]
#  [  7   0]]
#
# learning
# [[518  19]
#  [  4   0]]
#
# library
# [[521  15]
#  [  5   0]]
#
# line
# [[449  82]
#  [  8   2]]
#
# linux
# [[513  17]
#  [ 11   0]]
#
# macos
# [[501  35]
#  [  5   0]]
#
# maven
# [[530   5]
#  [  6   0]]
#
# memory
# [[505  31]
#  [  4   1]]
#
# mongodb
# [[516  17]
#  [  5   3]]
#
# multithreading
# [[466  61]
#  [ 13   1]]
#
# mvc
# [[436  85]
#  [ 17   3]]
#
# mysql
# [[522   6]
#  [ 12   1]]
#
# net
# [[485   0]
#  [ 56   0]]
#
# node
# [[525   7]
#  [  9   0]]
#
# numpy
# [[515  17]
#  [  8   1]]
#
# objective
# [[512   0]
#  [ 29   0]]
#
# optimization
# [[487  43]
#  [  8   3]]
#
# panda
# [[412 120]
#  [  7   2]]
#
# performance
# [[497  35]
#  [  9   0]]
#
# php
# [[481  44]
#  [ 15   1]]
#
# postgresql
# [[533   2]
#  [  6   0]]
#
# processing
# [[529   5]
#  [  7   0]]
#
# python
# [[450  21]
#  [ 61   9]]
#
# r
# [[532   0]
#  [  9   0]]
#
# rail
# [[523   5]
#  [ 13   0]]
#
# reactjs
# [[537   1]
#  [  3   0]]
#
# rest
# [[533   3]
#  [  5   0]]
#
# ruby
# [[508  19]
#  [ 14   0]]
#
# security
# [[512  24]
#  [  4   1]]
#
# selenium
# [[521  15]
#  [  5   0]]
#
# server
# [[236 293]
#  [  5   7]]
#
# service
# [[530   0]
#  [ 11   0]]
#
# shell
# [[521  14]
#  [  6   0]]
#
# spark
# [[478  61]
#  [  1   1]]
#
# spring
# [[505  15]
#  [ 20   1]]
#
# sql
# [[469  49]
#  [ 22   1]]
#
# string
# [[456  74]
#  [ 11   0]]
#
# studio
# [[466  57]
#  [ 15   3]]
#
# swift
# [[445  79]
#  [ 14   3]]
#
# testing
# [[525  11]
#  [  5   0]]
#
# touch
# [[527   3]
#  [ 10   1]]
#
# type
# [[528   8]
#  [  5   0]]
#
# ubuntu
# [[513  24]
#  [  4   0]]
#
# video
# [[485  52]
#  [  4   0]]
#
# visual
# [[507  22]
#  [ 12   0]]
#
# web
# [[522   0]
#  [ 19   0]]
#
# window
# [[502  22]
#  [ 17   0]]
#
# wpf
# [[390 141]
#  [ 10   0]]
#
# x
# [[493  31]
#  [ 16   1]]
#
# xcode
# [[485  39]
#  [ 16   1]]
#
# xml
# [[526  10]
#  [  5   0]]

# %% [markdown]
# Exctracting feature importance

# %%
def print_top10(feature_names, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("--------------------------------------------")
        print("%s: %s" % (class_label,
              " ".join(feature_names[j] for j in top10)))
        print("--------------------------------------------")

# %%
feature_names = vectorizer_X.get_feature_names()

# %%
print_top10(feature_names, best_model, multilabel_binarizer.classes_)
# Out:
# --------------------------------------------
# ajax: 11 09-11 05 01 -gt 00 1000 10 12 100
# --------------------------------------------
# --------------------------------------------
# algorithm: 09-11 11 05 10 --- -gt -o 01 -i 12
# --------------------------------------------
# --------------------------------------------
# amazon: 00 05 -gt -1 09-11 11 01 12 100 -o
# --------------------------------------------
# --------------------------------------------
# android: 100 05 -gt -1 01 -i 10 11 00 ---
# --------------------------------------------
# --------------------------------------------
# angular: -o 05 11 09-11 -i 100 --- -gt 12 01
# --------------------------------------------
# --------------------------------------------
# apache: -1 -gt -o 100 09-11 11 12 -i 00 1000
# --------------------------------------------
# --------------------------------------------
# api: 11 1000 --- 00 05 -o 01 12 -i 100
# --------------------------------------------
# --------------------------------------------
# array: 05 -gt 1000 11 12 -i -o 01 --- 100
# --------------------------------------------
# --------------------------------------------
# asp: 100 00 -i 01 11 05 --- 12 10 -gt
# --------------------------------------------
# --------------------------------------------
# authentication: -gt 1000 -1 12 09-11 --- 11 01 -o -i
# --------------------------------------------
# --------------------------------------------
# bash: 01 -i 00 12 10 -o 1000 05 100 -gt
# --------------------------------------------
# --------------------------------------------
# build: 05 00 01 09-11 --- 12 11 100 -i 10
# --------------------------------------------
# --------------------------------------------
# c: 05 1000 -o 100 00 09-11 -- -gt -i ---
# --------------------------------------------
# --------------------------------------------
# chrome: 00 -i --- 09-11 11 -o -gt 10 01 12
# --------------------------------------------
# --------------------------------------------
# class: -gt -i --- 11 -o 1000 100 09-11 12 01
# --------------------------------------------
# --------------------------------------------
# cocoa: 10 1000 11 --- 01 12 09-11 100 -o -gt
# --------------------------------------------
# --------------------------------------------
# code: -i 01 09-11 1000 11 00 100 -1 12 -gt
# --------------------------------------------
# --------------------------------------------
# command: 05 12 00 100 --- 09-11 11 -gt 1000 01
# --------------------------------------------
# --------------------------------------------
# core: 1000 -1 --- 100 10 12 -gt 11 00 -i
# --------------------------------------------
# --------------------------------------------
# cs: 00 100 11 -o 09-11 10 -i 05 -gt 1000
# --------------------------------------------
# --------------------------------------------
# data: -gt -i --- 10 01 1000 09-11 05 -1 12
# --------------------------------------------
# --------------------------------------------
# database: -1 -i 00 11 1000 -gt 12 09-11 -o 100
# --------------------------------------------
# --------------------------------------------
# dataframe: -o 12 09-11 00 1000 05 -i 01 100 -gt
# --------------------------------------------
# --------------------------------------------
# design: 12 01 10 -i 100 -1 05 -o 00 09-11
# --------------------------------------------
# --------------------------------------------
# django: 10 -gt 12 09-11 -1 1000 -o -i 05 100
# --------------------------------------------
# --------------------------------------------
# eclipse: 00 01 11 100 --- -1 05 -i -gt 10
# --------------------------------------------
# --------------------------------------------
# entity: 11 1000 -i 09-11 01 100 10 -gt -o 12
# --------------------------------------------
# --------------------------------------------
# event: 05 -i --- -o 1000 01 09-11 10 12 -gt
# --------------------------------------------
# --------------------------------------------
# facebook: -gt 01 --- -i 05 00 1000 -1 12 -o
# --------------------------------------------
# --------------------------------------------
# file: 00 11 01 05 1000 09-11 12 -i 10 100
# --------------------------------------------
# --------------------------------------------
# framework: -1 05 --- 10 1000 -o -gt 100 -i 12
# --------------------------------------------
# --------------------------------------------
# function: -i -1 05 10 -gt 11 01 -o 100 12
# --------------------------------------------
# --------------------------------------------
# git: -o 05 11 00 --- -gt 1000 01 10 12
# --------------------------------------------
# --------------------------------------------
# google: 05 00 --- -o -i 11 12 100 01 -gt
# --------------------------------------------
# --------------------------------------------
# gradle: -i 09-11 -gt 00 100 12 01 1000 10 11
# --------------------------------------------
# --------------------------------------------
# hibernate: -1 11 05 100 12 00 --- 10 -i 09-11
# --------------------------------------------
# --------------------------------------------
# html: 100 1000 11 01 --- -i 05 10 12 -gt
# --------------------------------------------
# --------------------------------------------
# http: 1000 -o --- 11 05 10 12 -gt 100 01
# --------------------------------------------
# --------------------------------------------
# image: 05 1000 09-11 -gt 11 12 01 -i -o 100
# --------------------------------------------
# --------------------------------------------
# interface: 01 11 -1 10 12 -gt -i 1000 05 -o
# --------------------------------------------
# --------------------------------------------
# io: 1000 -o 09-11 -- --- 10 -i 11 05 01
# --------------------------------------------
# --------------------------------------------
# iphone: --- 01 12 -1 -i 09-11 05 11 00 -o
# --------------------------------------------
# --------------------------------------------
# j: 09-11 1000 -1 01 -gt -o 11 --- 12 100
# --------------------------------------------
# --------------------------------------------
# java: 1000 --- -1 01 09-11 100 05 -gt -o 11
# --------------------------------------------
# --------------------------------------------
# javascript: -o --- 100 09-11 1000 11 -gt 01 10 12
# --------------------------------------------
# --------------------------------------------
# jpa: 12 05 11 -gt 00 09-11 1000 10 100 -i
# --------------------------------------------
# --------------------------------------------
# jquery: 1000 09-11 11 -o 100 00 -i --- 10 12
# --------------------------------------------
# --------------------------------------------
# json: 05 -i --- 11 100 -o 10 01 -gt 12
# --------------------------------------------
# --------------------------------------------
# laravel: -i 11 10 05 -gt 01 12 100 -o 09-11
# --------------------------------------------
# --------------------------------------------
# layout: 05 09-11 01 -i 100 1000 10 -o -gt 11
# --------------------------------------------
# --------------------------------------------
# learning: 10 00 09-11 1000 05 01 -i -gt 100 -o
# --------------------------------------------
# --------------------------------------------
# library: 09-11 --- 05 100 -gt -o 1000 00 01 11
# --------------------------------------------
# --------------------------------------------
# line: 11 10 09-11 -gt 100 -i 1000 --- 12 01
# --------------------------------------------
# --------------------------------------------
# linux: 00 12 -1 05 01 --- 11 -o -i 1000
# --------------------------------------------
# --------------------------------------------
# macos: 1000 01 05 -i --- -gt -o 12 09-11 100
# --------------------------------------------
# --------------------------------------------
# maven: 01 -i --- 100 1000 10 05 -gt 00 12
# --------------------------------------------
# --------------------------------------------
# memory: --- 12 10 -1 00 1000 01 05 -gt -i
# --------------------------------------------
# --------------------------------------------
# mongodb: 100 -i -gt 09-11 --- 10 05 12 -o 01
# --------------------------------------------
# --------------------------------------------
# multithreading: 11 10 --- 12 1000 -1 09-11 -gt -o 05
# --------------------------------------------
# --------------------------------------------
# mvc: -gt --- 01 -o 00 05 -i 100 10 12
# --------------------------------------------
# --------------------------------------------
# mysql: --- 00 10 01 100 11 -1 -i 05 1000
# --------------------------------------------
# --------------------------------------------
# net: 05 09-11 11 -gt --- 1000 01 -i 10 -o
# --------------------------------------------
# --------------------------------------------
# node: -i 1000 -1 11 --- -o -gt 01 12 100
# --------------------------------------------
# --------------------------------------------
# numpy: -1 09-11 -o 100 12 11 10 --- -i 05
# --------------------------------------------
# --------------------------------------------
# objective: 10 11 12 -1 --- 01 -i 1000 09-11 100
# --------------------------------------------
# --------------------------------------------
# optimization: 10 00 11 -o 09-11 -1 1000 05 100 12
# --------------------------------------------
# --------------------------------------------
# panda: 05 10 00 -i 09-11 100 11 01 12 -gt
# --------------------------------------------
# --------------------------------------------
# performance: 11 -o 09-11 100 -i --- -gt 05 12 01
# --------------------------------------------
# --------------------------------------------
# php: 01 --- -1 -o 12 100 00 1000 09-11 -i
# --------------------------------------------
# --------------------------------------------
# postgresql: --- -o 1000 10 100 05 01 -gt 12 -i
# --------------------------------------------
# --------------------------------------------
# processing: 01 11 -1 -o --- 00 10 1000 -i 05
# --------------------------------------------
# --------------------------------------------
# python: -gt 01 10 100 00 05 -i 1000 -o 12
# --------------------------------------------
# --------------------------------------------
# r: -1 11 -gt 09-11 10 --- -o 01 100 12
# --------------------------------------------
# --------------------------------------------
# rail: -i 10 -gt 05 -o 1000 100 01 09-11 12
# --------------------------------------------
# --------------------------------------------
# reactjs: -i 100 1000 05 -gt 01 -o 11 00 10
# --------------------------------------------
# --------------------------------------------
# rest: 11 10 05 100 -gt -o -i --- 12 01
# --------------------------------------------
# --------------------------------------------
# ruby: 05 --- 01 1000 10 -gt -o 100 12 -i
# --------------------------------------------
# --------------------------------------------
# security: 12 -i 11 00 05 1000 100 09-11 -gt -o
# --------------------------------------------
# --------------------------------------------
# selenium: 05 09-11 -gt -o 11 --- -i -1 01 100
# --------------------------------------------
# --------------------------------------------
# server: 10 11 -- 01 -o 00 1000 --- -i 05
# --------------------------------------------
# --------------------------------------------
# service: 09-11 05 10 -i -gt 01 100 -o 11 12
# --------------------------------------------
# --------------------------------------------
# shell: -1 1000 12 00 -gt 01 05 -i 09-11 100
# --------------------------------------------
# --------------------------------------------
# spark: 10 --- 01 12 09-11 1000 00 100 -1 -gt
# --------------------------------------------
# --------------------------------------------
# spring: --- 00 11 09-11 100 12 1000 10 -gt -i
# --------------------------------------------
# --------------------------------------------
# sql: 1000 09-11 -gt 12 01 10 --- 00 -i -o
# --------------------------------------------
# --------------------------------------------
# string: -1 -o 01 05 1000 -i 09-11 10 00 -gt
# --------------------------------------------
# --------------------------------------------
# studio: 11 05 100 1000 -1 -o 01 -i 12 10
# --------------------------------------------
# --------------------------------------------
# swift: 1000 100 00 11 -1 10 05 -gt 12 01
# --------------------------------------------
# --------------------------------------------
# testing: 01 -1 11 00 -o 05 -i 12 1000 10
# --------------------------------------------
# --------------------------------------------
# touch: -i -gt 10 05 1000 -o 01 100 12 11
# --------------------------------------------
# --------------------------------------------
# type: 11 10 1000 -i 01 00 -o 100 12 -1
# --------------------------------------------
# --------------------------------------------
# ubuntu: -1 100 05 -gt --- 10 01 11 -o 12
# --------------------------------------------
# --------------------------------------------
# video: 1000 00 11 -gt -i 100 01 05 -o 12
# --------------------------------------------
# --------------------------------------------
# visual: 1000 05 00 01 -o 12 -gt 11 100 10
# --------------------------------------------
# --------------------------------------------
# web: 10 100 12 -o 11 -gt 05 -i 01 00
# --------------------------------------------
# --------------------------------------------
# window: 05 100 09-11 --- 11 1000 -o 12 -gt 10
# --------------------------------------------
# --------------------------------------------
# wpf: -- 00 10 --- 11 -gt 01 -o 12 1000
# --------------------------------------------
# --------------------------------------------
# x: 00 11 09-11 1000 -o 12 -i 05 100 -1
# --------------------------------------------
# --------------------------------------------
# xcode: 01 -gt 05 1000 00 09-11 -i -o 100 10
# --------------------------------------------
# --------------------------------------------
# xml: -i 1000 100 00 01 10 --- 09-11 05 -gt
# --------------------------------------------

# %%
#pip install transformers

# %% [markdown]
# #BERT

# %%
df1
# Out:
#             Id                                        full_review  \
# 0     13680954  green dao vs orm lite vs active android pwhich...
# 1       997482  java support default parameter value pi come a...
# 2     32274369  convert zoneddatetime date pi try set server a...
# 3       161315  rubyruby rail memory leak detection pi write s...
# 4     11169418  numpy style array c pare c c libs numpy-like a...
# ...        ...                                                ...
# 2786  63373245  add debug symbols buildgradle pi create androi...
# 2787   9062475  difference document style rpc style communicat...
# 2788  35884752  error slickjs uncaught typeerror cannot read p...
# 2790  12042853  difference maphttproute maproute pwhy use mapr...
# 2792  22453273  visualize large network r pnetwork visualizati...
#
#                                              clean_tags  \
# 0     android ormlite greendao activeandroid droidparts
# 1     java method parameter overloading default para...
# 2     java java java util date datetime conversion z...
# 3        ruby rail ruby memory memory leak coding style
# 4                  c array python x numpy dynamic array
# ...                                                 ...
# 2786  android flutter debugging release android app ...
# 2787                    web service soap wsdl jax w rpc
# 2788        jquery ruby rail slider nested form slick j
# 2790  c asp net asp net mvc asp net web api asp net ...
# 2792  r graph visualization social networking graph ...
#
#                                                    Tags
# 0                                             [android]
# 1                                                [java]
# 2                                    [java, java, java]
# 3                    [ruby, rail, ruby, memory, memory]
# 4                   [c, array, python, x, numpy, array]
# ...                                                 ...
# 2786                                 [android, android]
# 2787                                     [web, service]
# 2788                            [jquery, ruby, rail, j]
# 2790  [c, asp, net, asp, net, mvc, asp, net, web, ap...
# 2792                                                [r]
#
# [2704 rows x 4 columns]

# %%
X = df1['full_review']
y = df1['Tags']

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1['full_review'],y_bin)
X_train.head(4)
# Out:
# 2211    flash unstyled content fouc firefox ff slow re...
# 597     dispatchsync vs dispatchasync main queue pbear...
# 308     distribute issue tracker git usable eclipse my...
# 2452    basic unit test c get start pafter read quite ...
# Name: full_review, dtype: object

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

### Let's create some mock data
def get_mock_up_data():
    #sentence_1 = 'Deep learning is super easy'
    #sentence_2 = 'Deep learning was super bad and too long'
    #sentence_3 = 'This is the best lecture of the camp!'

    X = df1['full_review']
    y = df1['Tags'] 

    ### Let's tokenize the vocabulary 
    tk = Tokenizer()
    tk.fit_on_texts(X)
    vocab_size = len(tk.word_index)
    print(f'There are {vocab_size} different words in your corpus')
    X_token = tk.texts_to_sequences(X)

    ### Pad the inputs
    X_pad = pad_sequences(X_token, dtype='float32', padding='post')
    
    return X_pad, y, vocab_size

X_pad, y, vocab_size = get_mock_up_data()
print("X_pad.shape", X_pad.shape)
X_pad
# Out:
# There are 48121 different words in your corpus
# X_pad.shape (2704, 2784)
# array([[1.7420e+03, 5.5360e+03, 2.8200e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.0100e+02, 1.9300e+02, 2.0100e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [2.4300e+02, 8.3620e+03, 3.0800e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        ...,
#        [2.7000e+01, 4.8069e+04, 3.3570e+03, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [2.5000e+02, 1.9147e+04, 1.9148e+04, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [3.6500e+03, 4.1500e+02, 5.7900e+02, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00]], dtype=float32)

# %%
#Our sentences we like to encode
sentences = df1['full_review'][0]
#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentences)

# %%
#Print the embeddings
for sentence, embedding in zip(sentences, embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
    print("")
# Out:
# Sentence: g
# Embedding: -0.011131429
#
# Sentence: r
# Embedding: -0.043429505
#
# Sentence: e
# Embedding: -0.002220663
#
# Sentence: e
# Embedding: -0.093296275
#
# Sentence: n
# Embedding: 0.04474518
#
# Sentence:
# Embedding: -0.018324357
#
# Sentence: d
# Embedding: 0.039171685
#
# Sentence: a
# Embedding: 0.109716125
#
# Sentence: o
# Embedding: -0.06421501
#
# Sentence:
# Embedding: 0.051182598
#
# Sentence: v
# Embedding: 0.048831206
#
# Sentence: s
# Embedding: -0.0065548373
#
# Sentence:
# Embedding: 0.028600119
#
# Sentence: o
# Embedding: -0.0334089
#
# Sentence: r
# Embedding: 0.109893024
#
# Sentence: m
# Embedding: 0.08628285
#
# Sentence:
# Embedding: 0.057155635
#
# Sentence: l
# Embedding: -0.011301543
#
# Sentence: i
# Embedding: 0.010791443
#
# Sentence: t
# Embedding: -0.070246615
#
# Sentence: e
# Embedding: 0.053595223
#
# Sentence:
# Embedding: -0.012578789
#
# Sentence: v
# Embedding: 0.029381137
#
# Sentence: s
# Embedding: -0.043632705
#
# Sentence:
# Embedding: -0.025217952
#
# Sentence: a
# Embedding: 0.00845188
#
# Sentence: c
# Embedding: 0.044764325
#
# Sentence: t
# Embedding: 0.021543257
#
# Sentence: i
# Embedding: 0.030437728
#
# Sentence: v
# Embedding: -0.067253664
#
# Sentence: e
# Embedding: -0.03303506
#
# Sentence:
# Embedding: 0.068479165
#
# Sentence: a
# Embedding: 0.019491239
#
# Sentence: n
# Embedding: 0.03700987
#
# Sentence: d
# Embedding: -0.07439201
#
# Sentence: r
# Embedding: -0.068819046
#
# Sentence: o
# Embedding: 0.0019356508
#
# Sentence: i
# Embedding: -0.05383005
#
# Sentence: d
# Embedding: -0.10710846
#
# Sentence:
# Embedding: -0.04530339
#
# Sentence: p
# Embedding: -0.05616738
#
# Sentence: w
# Embedding: -0.01936277
#
# Sentence: h
# Embedding: -0.04614363
#
# Sentence: i
# Embedding: -0.05561805
#
# Sentence: c
# Embedding: 0.0077388287
#
# Sentence: h
# Embedding: -0.022354705
#
# Sentence:
# Embedding: -0.041687887
#
# Sentence: b
# Embedding: 0.012471591
#
# Sentence: e
# Embedding: 0.011727643
#
# Sentence: s
# Embedding: -0.037230074
#
# Sentence: t
# Embedding: -0.030247869
#
# Sentence:
# Embedding: -0.0736969
#
# Sentence: o
# Embedding: 0.0081596235
#
# Sentence: r
# Embedding: -0.0015626574
#
# Sentence: m
# Embedding: -0.05686568
#
# Sentence:
# Embedding: 0.04687992
#
# Sentence: t
# Embedding: 0.0013057999
#
# Sentence: o
# Embedding: -0.00052144343
#
# Sentence: o
# Embedding: -0.021164883
#
# Sentence: l
# Embedding: -0.06314006
#
# Sentence:
# Embedding: -0.017144622
#
# Sentence: a
# Embedding: -0.031050354
#
# Sentence: v
# Embedding: -0.07804448
#
# Sentence: a
# Embedding: 0.09522309
#
# Sentence: i
# Embedding: -0.05496716
#
# Sentence: l
# Embedding: 0.097958006
#
# Sentence: a
# Embedding: 0.059462737
#
# Sentence: b
# Embedding: 0.019267604
#
# Sentence: l
# Embedding: 0.05677561
#
# Sentence: e
# Embedding: -0.11030492
#
# Sentence:
# Embedding: -0.061328873
#
# Sentence: a
# Embedding: -0.0016942502
#
# Sentence: n
# Embedding: 0.04404364
#
# Sentence: d
# Embedding: 0.00024383146
#
# Sentence: r
# Embedding: -0.060492795
#
# Sentence: o
# Embedding: 0.02424287
#
# Sentence: i
# Embedding: 0.047156893
#
# Sentence: d
# Embedding: 0.024057036
#
# Sentence:
# Embedding: -0.0409894
#
# Sentence: p
# Embedding: -0.095889464
#
# Sentence:
# Embedding: -0.0041160495
#
# Sentence: p
# Embedding: 0.063896626
#
# Sentence: i
# Embedding: -0.09136802
#
# Sentence:
# Embedding: 0.05926552
#
# Sentence: s
# Embedding: 0.063921764
#
# Sentence: e
# Embedding: 0.0146173965
#
# Sentence: e
# Embedding: 0.008575817
#
# Sentence:
# Embedding: 0.027615901
#
# Sentence: o
# Embedding: -0.020011151
#
# Sentence: r
# Embedding: 0.019693494
#
# Sentence: m
# Embedding: -0.009123583
#
# Sentence: l
# Embedding: 0.09122995
#
# Sentence: i
# Embedding: 0.03275898
#
# Sentence: t
# Embedding: -0.021344373
#
# Sentence: e
# Embedding: -0.033426676
#
# Sentence:
# Embedding: -0.0012759969
#
# Sentence: a
# Embedding: 0.019266322
#
# Sentence: c
# Embedding: -0.09123978
#
# Sentence: t
# Embedding: -0.028957512
#
# Sentence: i
# Embedding: 0.030359656
#
# Sentence: v
# Embedding: -0.01627672
#
# Sentence: e
# Embedding: 0.046847284
#
# Sentence: a
# Embedding: -0.037620932
#
# Sentence: n
# Embedding: -0.07805348
#
# Sentence: d
# Embedding: -0.037277855
#
# Sentence: r
# Embedding: 0.017993534
#
# Sentence: o
# Embedding: -0.014615936
#
# Sentence: i
# Embedding: -0.02144883
#
# Sentence: d
# Embedding: 0.049816743
#
# Sentence:
# Embedding: 0.09491919
#
# Sentence: d
# Embedding: 0.007245046
#
# Sentence: i
# Embedding: -0.089381866
#
# Sentence: s
# Embedding: -0.034875076
#
# Sentence: c
# Embedding: -0.05591815
#
# Sentence: u
# Embedding: 0.023538187
#
# Sentence: s
# Embedding: 0.024737919
#
# Sentence: s
# Embedding: 0.022835618
#
# Sentence:
# Embedding: 0.020300655
#
# Sentence: a
# Embedding: 0.061882153
#
# Sentence: c
# Embedding: -0.032354508
#
# Sentence: r
# Embedding: -0.055722583
#
# Sentence: o
# Embedding: -0.09338145
#
# Sentence: s
# Embedding: -0.057142995
#
# Sentence: s
# Embedding: -0.010070174
#
# Sentence:
# Embedding: 0.026303465
#
# Sentence: f
# Embedding: -0.0061259796
#
# Sentence: r
# Embedding: -0.033568006
#
# Sentence: i
# Embedding: 1.1794202e-32
#
# Sentence: e
# Embedding: 0.05107996
#
# Sentence: n
# Embedding: 0.024065934
#
# Sentence: d
# Embedding: -0.03412783
#
# Sentence:
# Embedding: -0.052789714
#
# Sentence: m
# Embedding: 0.045930274
#
# Sentence: i
# Embedding: 0.05709353
#
# Sentence: n
# Embedding: 0.03585699
#
# Sentence: e
# Embedding: 0.084058136
#
# Sentence:
# Embedding: -0.05917797
#
# Sentence: s
# Embedding: -0.10528236
#
# Sentence: u
# Embedding: 0.039718322
#
# Sentence: g
# Embedding: 0.03021028
#
# Sentence: g
# Embedding: -0.11000119
#
# Sentence: e
# Embedding: 0.0057775658
#
# Sentence: s
# Embedding: 0.09210115
#
# Sentence: t
# Embedding: -0.15920025
#
# Sentence:
# Embedding: 0.00037051743
#
# Sentence: u
# Embedding: 0.09090089
#
# Sentence: s
# Embedding: -0.073253416
#
# Sentence: e
# Embedding: 0.010675083
#
# Sentence:
# Embedding: -0.030181473
#
# Sentence: g
# Embedding: -0.04968278
#
# Sentence: r
# Embedding: 0.006502419
#
# Sentence: e
# Embedding: 0.04690915
#
# Sentence: e
# Embedding: 0.111076504
#
# Sentence: n
# Embedding: 0.05575159
#
# Sentence: d
# Embedding: 0.076037094
#
# Sentence: a
# Embedding: -0.0018554329
#
# Sentence: o
# Embedding: 0.008325721
#
# Sentence:
# Embedding: -0.045949973
#
# Sentence: l
# Embedding: 0.0074387635
#
# Sentence: o
# Embedding: -0.07672951
#
# Sentence: o
# Embedding: -9.0961796e-05
#
# Sentence: k
# Embedding: -0.0076274304
#
# Sentence:
# Embedding: -0.060156655
#
# Sentence: k
# Embedding: -0.012543793
#
# Sentence: n
# Embedding: -0.1540851
#
# Sentence: o
# Embedding: -0.013066231
#
# Sentence: w
# Embedding: 0.014240192
#
# Sentence: l
# Embedding: -0.070236005
#
# Sentence: e
# Embedding: -0.13717836
#
# Sentence: d
# Embedding: 0.046894617
#
# Sentence: g
# Embedding: 0.010161513
#
# Sentence: e
# Embedding: 0.0053976695
#
# Sentence:
# Embedding: 0.058344685
#
# Sentence: r
# Embedding: 0.047090814
#
# Sentence: e
# Embedding: -0.06361719
#
# Sentence: s
# Embedding: -0.002922119
#
# Sentence: o
# Embedding: -0.0062422124
#
# Sentence: u
# Embedding: 0.0147476485
#
# Sentence: r
# Embedding: 0.018168248
#
# Sentence: c
# Embedding: 0.016007515
#
# Sentence: e
# Embedding: -0.021646863
#
# Sentence:
# Embedding: 0.06766263
#
# Sentence: h
# Embedding: -0.01112248
#
# Sentence: e
# Embedding: -0.021470385
#
# Sentence: l
# Embedding: -0.017950134
#
# Sentence: p
# Embedding: -0.0076683895
#
# Sentence:
# Embedding: -0.022843458
#
# Sentence: d
# Embedding: -0.05283767
#
# Sentence: e
# Embedding: 0.029390123
#
# Sentence: c
# Embedding: 0.053705223
#
# Sentence: i
# Embedding: -0.0020678325
#
# Sentence: s
# Embedding: -0.024323558
#
# Sentence: i
# Embedding: -0.016347986
#
# Sentence: o
# Embedding: 0.0167099
#
# Sentence: n
# Embedding: 0.013784176
#
# Sentence:
# Embedding: -0.0636553
#
# Sentence: m
# Embedding: 0.0077611324
#
# Sentence: a
# Embedding: 0.0008441966
#
# Sentence: k
# Embedding: 0.01734997
#
# Sentence: i
# Embedding: -0.05170096
#
# Sentence: n
# Embedding: 0.105209544
#
# Sentence: g
# Embedding: 0.025623137
#
# Sentence: p
# Embedding: -0.019394426
#
# Sentence:
# Embedding: 0.018522305
#
# Sentence: p
# Embedding: -0.025106061
#
# Sentence: f
# Embedding: -0.07973548
#
# Sentence: e
# Embedding: -0.091885574
#
# Sentence: a
# Embedding: 0.019707356
#
# Sentence: t
# Embedding: -0.025516162
#
# Sentence: u
# Embedding: -0.0011813358
#
# Sentence: r
# Embedding: -0.022895787
#
# Sentence: e
# Embedding: -0.010345526
#
# Sentence: s
# Embedding: -0.03097124
#
# Sentence:
# Embedding: -0.008343095
#
# Sentence: l
# Embedding: 0.039303277
#
# Sentence: o
# Embedding: -0.0290597
#
# Sentence: o
# Embedding: -0.0312658
#
# Sentence: k
# Embedding: 0.12121842
#
# Sentence:
# Embedding: -0.00039336373
#
# Sentence: j
# Embedding: 0.06907957
#
# Sentence: u
# Embedding: 0.01926794
#
# Sentence: d
# Embedding: 0.0017744564
#
# Sentence: g
# Embedding: 0.020701
#
# Sentence: e
# Embedding: -1.0774472e-32
#
# Sentence:
# Embedding: -0.084616765
#
# Sentence: f
# Embedding: -0.023427583
#
# Sentence: r
# Embedding: 0.0039634043
#
# Sentence: e
# Embedding: 0.052389037
#
# Sentence: e
# Embedding: 0.07935343
#
# Sentence: l
# Embedding: -0.0759978
#
# Sentence: y
# Embedding: -0.037705187
#
# Sentence:
# Embedding: 0.04387041
#
# Sentence: a
# Embedding: 0.06348549
#
# Sentence: v
# Embedding: -0.025358506
#
# Sentence: a
# Embedding: -0.023183266
#
# Sentence: i
# Embedding: 0.02777434
#
# Sentence: l
# Embedding: 0.005310387
#
# Sentence: a
# Embedding: 0.018251749
#
# Sentence: b
# Embedding: 0.05443673
#
# Sentence: l
# Embedding: 0.02063467
#
# Sentence: e
# Embedding: -0.00025714634
#
# Sentence:
# Embedding: -0.032632336
#
# Sentence: o
# Embedding: -0.0012961117
#
# Sentence: p
# Embedding: 0.04335996
#
# Sentence: e
# Embedding: -0.04622969
#
# Sentence: n
# Embedding: 0.13343045
#
# Sentence:
# Embedding: -0.021278925
#
# Sentence: s
# Embedding: 0.04636997
#
# Sentence: o
# Embedding: -0.041036893
#
# Sentence: u
# Embedding: 0.018653838
#
# Sentence: r
# Embedding: -0.018636608
#
# Sentence: c
# Embedding: 0.014642008
#
# Sentence: e
# Embedding: -0.06224865
#
# Sentence:
# Embedding: -0.0021145376
#
# Sentence: g
# Embedding: 0.042621728
#
# Sentence: o
# Embedding: -0.010025331
#
# Sentence: o
# Embedding: -0.01899871
#
# Sentence: d
# Embedding: 0.026245993
#
# Sentence:
# Embedding: 0.029428119
#
# Sentence: d
# Embedding: -0.006914633
#
# Sentence: o
# Embedding: 0.029189592
#
# Sentence: c
# Embedding: -0.028060775
#
# Sentence: u
# Embedding: -0.020467136
#
# Sentence: m
# Embedding: 0.07528321
#
# Sentence: e
# Embedding: 0.048807792
#
# Sentence: n
# Embedding: -0.008552568
#
# Sentence: t
# Embedding: -0.00080876396
#
# Sentence: a
# Embedding: -0.114005424
#
# Sentence: t
# Embedding: -0.0761569
#
# Sentence: i
# Embedding: -0.041419383
#
# Sentence: o
# Embedding: -0.09502131
#
# Sentence: n
# Embedding: -0.00067715015
#
# Sentence:
# Embedding: -0.071814716
#
# Sentence: a
# Embedding: -0.025748415
#
# Sentence: c
# Embedding: 0.07810615
#
# Sentence: t
# Embedding: 0.03632508
#
# Sentence: i
# Embedding: 0.0016936305
#
# Sentence: v
# Embedding: -0.056423265
#
# Sentence: e
# Embedding: 0.027608711
#
# Sentence:
# Embedding: -0.017922124
#
# Sentence: f
# Embedding: -0.021153739
#
# Sentence: o
# Embedding: -0.049609806
#
# Sentence: r
# Embedding: -0.06894544
#
# Sentence: u
# Embedding: -0.059570827
#
# Sentence: m
# Embedding: 0.038958706
#
# Sentence: s
# Embedding: -0.018930702
#
# Sentence:
# Embedding: -0.061620023
#
# Sentence: s
# Embedding: 0.11099528
#
# Sentence: t
# Embedding: -0.058599755
#
# Sentence: a
# Embedding: 0.059318673
#
# Sentence: b
# Embedding: 0.071619906
#
# Sentence: l
# Embedding: 0.0338355
#
# Sentence: e
# Embedding: -0.09840395
#
# Sentence:
# Embedding: 0.005657547
#
# Sentence: v
# Embedding: -0.050332446
#
# Sentence: e
# Embedding: 0.021638116
#
# Sentence: r
# Embedding: 0.0077594286
#
# Sentence: s
# Embedding: 0.018060401
#
# Sentence: i
# Embedding: 0.025657408
#
# Sentence: o
# Embedding: 0.017413441
#
# Sentence: n
# Embedding: -0.03867907
#
# Sentence:
# Embedding: -0.012489506
#
# Sentence: a
# Embedding: -0.074676484
#
# Sentence: v
# Embedding: -0.010907469
#
# Sentence: a
# Embedding: 0.01279712
#
# Sentence: i
# Embedding: 0.07013962
#
# Sentence: l
# Embedding: -0.039355014
#
# Sentence: a
# Embedding: 0.043329578
#
# Sentence: b
# Embedding: -0.07888491
#
# Sentence: l
# Embedding: 0.07234635
#
# Sentence: e
# Embedding: -0.022165982
#
# Sentence:
# Embedding: -0.00999673
#
# Sentence: e
# Embedding: -0.026541118
#
# Sentence: t
# Embedding: 0.0072748247
#
# Sentence: c
# Embedding: -0.045845557
#
# Sentence:
# Embedding: 0.0420737
#
# Sentence: e
# Embedding: -0.013217242
#
# Sentence: v
# Embedding: 0.09348115
#
# Sentence: e
# Embedding: -0.006178286
#
# Sentence: r
# Embedding: -3.736076e-08
#
# Sentence:
# Embedding: 0.09293665
#
# Sentence: r
# Embedding: -0.10597318
#
# Sentence: e
# Embedding: 0.13969755
#
# Sentence: q
# Embedding: 0.019224856
#
# Sentence: u
# Embedding: 0.0022600633
#
# Sentence: i
# Embedding: -0.07574833
#
# Sentence: r
# Embedding: 0.0140025895
#
# Sentence: e
# Embedding: 0.025711419
#
# Sentence:
# Embedding: 0.023520658
#
# Sentence: d
# Embedding: 0.02811103
#
# Sentence: e
# Embedding: 0.01836352
#
# Sentence: v
# Embedding: -0.04042452
#
# Sentence: e
# Embedding: -0.061267387
#
# Sentence: l
# Embedding: 0.06159066
#
# Sentence: o
# Embedding: 0.09046476
#
# Sentence: p
# Embedding: -0.025849806
#
# Sentence: e
# Embedding: 0.04646069
#
# Sentence: r
# Embedding: 0.021830266
#
# Sentence: p
# Embedding: -0.067662366

# %%
#pip install -U sentence-transformers

# %%
#pip install ipywidgets==7.4.2

# %%
#pip install ipywidgets --user

# %%
#pip install ipywidgets

# %%
#pip install widgetsnbextension

# %%
X = df1['full_review']
y = df1['Tags']

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %% [markdown]
# # BERT

# %%
import tensorflow as tf
# import tensorflow_hub as hub
import tensorflow.keras
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import metrics as kmetrics
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

# Bert
import os
import transformers
from transformers import *

os.environ["TF_KERAS"]='1'

# %%
print(tf.__version__)
print(tensorflow.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())
# Out:
# 2.10.0
# 2.10.0
# Num GPUs Available:  0
# True

# %% [markdown]
# ## Fonctions communes

# %%
# Fonction de préparation des sentences
def bert_inp_fct(sentences, bert_tokenizer, max_length) :
    input_ids=[]
    token_type_ids = []
    attention_mask=[]
    bert_inp_tot = []

    for sent in sentences:
        bert_inp = bert_tokenizer.encode_plus(sent,
                                              add_special_tokens = True,
                                              max_length = max_length,
                                              padding='max_length',
                                              return_attention_mask = True, 
                                              return_token_type_ids=True,
                                              truncation=True,
                                              return_tensors="tf")
    
        input_ids.append(bert_inp['input_ids'][0])
        token_type_ids.append(bert_inp['token_type_ids'][0])
        attention_mask.append(bert_inp['attention_mask'][0])
        bert_inp_tot.append((bert_inp['input_ids'][0], 
                             bert_inp['token_type_ids'][0], 
                             bert_inp['attention_mask'][0]))

    input_ids = np.asarray(input_ids)
    token_type_ids = np.asarray(token_type_ids)
    attention_mask = np.array(attention_mask)
    
    return input_ids, token_type_ids, attention_mask, bert_inp_tot
    

# Fonction de création des features
def feature_BERT_fct(model, model_type, sentences, max_length, b_size, mode='HF') :
    batch_size = b_size
    batch_size_pred = b_size
    bert_tokenizer = AutoTokenizer.from_pretrained(model_type)
    time1 = time.time()

    for step in range(len(sentences)//batch_size) :
        idx = step*batch_size
        input_ids, token_type_ids, attention_mask, bert_inp_tot = bert_inp_fct(sentences[idx:idx+batch_size], 
                                                                      bert_tokenizer, max_length)
        
        if mode=='HF' :    # Bert HuggingFace
            outputs = model.predict([input_ids, attention_mask, token_type_ids], batch_size=batch_size_pred)
            last_hidden_states = outputs.last_hidden_state

        if mode=='TFhub' : # Bert Tensorflow Hub
            text_preprocessed = {"input_word_ids" : input_ids, 
                                 "input_mask" : attention_mask, 
                                 "input_type_ids" : token_type_ids}
            outputs = model(text_preprocessed)
            last_hidden_states = outputs['sequence_output']
             
        if step ==0 :
            last_hidden_states_tot = last_hidden_states
            last_hidden_states_tot_0 = last_hidden_states
        else :
            last_hidden_states_tot = np.concatenate((last_hidden_states_tot,last_hidden_states))
    
    features_bert = np.array(last_hidden_states_tot).mean(axis=1)
    
    time2 = np.round(time.time() - time1,0)
    print("temps traitement : ", time2)
     
    return features_bert, last_hidden_states_tot

# %% [markdown]
# ## BERT HuggingFace

# %% [markdown]
# ### 'bert-base-uncased'

# %%
max_length = 64
batch_size = 10
model_type = 'bert-base-uncased'
model = TFAutoModel.from_pretrained(model_type)
sentences = df1['full_review'].to_list()
# Out:
# loading configuration file config.json from cache at C:\Users\ray63/.cache\huggingface\hub\models--bert-base-uncased\snapshots\5546055f03398095e385d7dc625e636cc8910bf2\config.json
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file tf_model.h5 from cache at C:\Users\ray63/.cache\huggingface\hub\models--bert-base-uncased\snapshots\5546055f03398095e385d7dc625e636cc8910bf2\tf_model.h5
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
# Création des features

features_bert, last_hidden_states_tot = feature_BERT_fct(model, model_type, sentences, 
                                                         max_length, batch_size, mode='HF')
# Out:
# loading configuration file config.json from cache at C:\Users\ray63/.cache\huggingface\hub\models--bert-base-uncased\snapshots\5546055f03398095e385d7dc625e636cc8910bf2\config.json
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading file vocab.txt from cache at C:\Users\ray63/.cache\huggingface\hub\models--bert-base-uncased\snapshots\5546055f03398095e385d7dc625e636cc8910bf2\vocab.txt
# loading file tokenizer.json from cache at C:\Users\ray63/.cache\huggingface\hub\models--bert-base-uncased\snapshots\5546055f03398095e385d7dc625e636cc8910bf2\tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at C:\Users\ray63/.cache\huggingface\hub\models--bert-base-uncased\snapshots\5546055f03398095e385d7dc625e636cc8910bf2\tokenizer_config.json
# loading configuration file config.json from cache at C:\Users\ray63/.cache\huggingface\hub\models--bert-base-uncased\snapshots\5546055f03398095e385d7dc625e636cc8910bf2\config.json
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 635ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 621ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 623ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 648ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 659ms/step
# temps traitement :  196.0

# %%
features_bert.shape
# Out:
# (2700, 768)

# %%
df1 = df1.sample(n = 2700,replace=True)

# %%
y = df1['Tags']
y.shape
# Out:
# (2700,)

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %%
y_bin.shape
# Out:
# (2700, 100)

# %% [markdown]
# # PCA

# %%
clf = TruncatedSVD(60)
Xpca = clf.fit_transform(features_bert)

# %%
clf.explained_variance_ratio_
# Out:
# array([0.02085971, 0.09980578, 0.07709412, 0.07525137, 0.04234245,
#        0.0328852 , 0.02949827, 0.02745288, 0.02407041, 0.02129617,
#        0.01825007, 0.01763354, 0.01564919, 0.01421888, 0.01347563,
#        0.01247714, 0.01128556, 0.01089022, 0.0095616 , 0.00928659,
#        0.00908455, 0.00872666, 0.00827455, 0.00788666, 0.00740298,
#        0.00725144, 0.00716268, 0.00683128, 0.00647574, 0.00639467,
#        0.00612979, 0.00603387, 0.00590984, 0.00560549, 0.00553238,
#        0.00536342, 0.005312  , 0.00517633, 0.00505512, 0.00504349,
#        0.00474127, 0.00459617, 0.00452782, 0.00432949, 0.00424783,
#        0.00418327, 0.00404752, 0.00389431, 0.00386438, 0.00384342,
#        0.00380623, 0.00375619, 0.00356825, 0.00345515, 0.00336505,
#        0.00321577, 0.00316637, 0.00310779, 0.00307646, 0.00303377],
#       dtype=float32)

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, 61), clf.explained_variance_ratio_.cumsum(),marker = "o", linestyle = "--")
plt.title("Explained Variance by Componants")
plt.xlabel("Nomber of componants")
plt.ylabel("Explained Variance")
# Out:
# Text(0, 0.5, 'Explained Variance')

# %%
clf = TruncatedSVD(50)
Xpca_features_bert = clf.fit_transform(features_bert)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Xpca_features_bert,y_bin, test_size = 0.2, random_state = 0)

# %%
def avg_jacard(y_true,y_pred):
    jacard = np.minimum(y_true,y_pred).sum(axis=1) / np.maximum(y_true,y_pred).sum(axis=1)    
    return jacard.mean()*100
    
def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    print("Jacard score: {}".format(avg_jacard(y_test, y_pred)))
    print("Hamming loss: {}".format(hamming_loss(y_pred, y_test)*100))
    print("---")

# %%
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.svm import LinearSVC
dummy = DummyClassifier()
sgd = SGDClassifier()
lr = LogisticRegression()
svc = LinearSVC()
perceptron = Perceptron()
pac = PassiveAggressiveClassifier()

for classifier in [dummy, sgd, lr, svc, perceptron, pac]:
    clf = OneVsRestClassifier(classifier)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print_score(y_pred, classifier)
# Out:
# Clf:  DummyClassifier
# Jacard score: 0.0
# Hamming loss: 2.6203703703703707
# ---
# Clf:  SGDClassifier
# Jacard score: 1.3029100529100528
# Hamming loss: 3.172222222222222
# ---
# Clf:  LogisticRegression
# Jacard score: 0.0
# Hamming loss: 2.6203703703703707
# ---
# Clf:  LinearSVC
# Jacard score: 0.0
# Hamming loss: 2.6203703703703707
# ---
# Clf:  Perceptron
# Jacard score: 2.174088771310993
# Hamming loss: 5.707407407407407
# ---
# Clf:  PassiveAggressiveClassifier
# Jacard score: 3.3805114638447966
# Hamming loss: 5.159259259259259
# ---

# %%
SGDClassifier
# Out:
# sklearn.linear_model._stochastic_gradient.SGDClassifier

# %%
sgd = SGDClassifier()
clf = OneVsRestClassifier(sgd)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, sgd)
# Out:
# Clf:  SGDClassifier
# Jacard score: 4.742504409171076
# Hamming loss: 3.585185185185185
# ---

# %%
OneVsRestClassifier
# Out:
# sklearn.multiclass.OneVsRestClassifier

# %%
lr = LogisticRegression()
clf = OneVsRestClassifier(lr)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, lr)
# Out:
# Clf:  LogisticRegression
# Jacard score: 0.0
# Hamming loss: 2.6203703703703707
# ---

# %%
RandomForestClassifier
# Out:
# sklearn.ensemble._forest.RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

print_score(y_pred, rfc)
# Out:
# Clf:  RandomForestClassifier
# Jacard score: 0.0
# Hamming loss: 2.6203703703703707
# ---

# %% [markdown]
# MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier()
mlpc.fit(X_train, y_train)

y_pred = mlpc.predict(X_test)

print_score(y_pred, mlpc)
# Out:
# Clf:  MLPClassifier
# Jacard score: 0.21781305114638447
# Hamming loss: 2.666666666666667
# ---

# %% [markdown]
# GridSearch CV on the best classifier

# %%
param_grid = {'estimator__C':[1,10,100,1000]
              }

# %%
svc = OneVsRestClassifier(LinearSVC())
CV_svc = model_selection.GridSearchCV(estimator=svc, param_grid=param_grid, cv= 5, verbose=10, scoring=make_scorer(avg_jacard,greater_is_better=True))
CV_svc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START estimator__C=1..............................................
# [CV 1/5; 1/4] END ...............estimator__C=1;, score=0.000 total time=   8.5s
# [CV 2/5; 1/4] START estimator__C=1..............................................
# [CV 2/5; 1/4] END ...............estimator__C=1;, score=0.000 total time=   8.2s
# [CV 3/5; 1/4] START estimator__C=1..............................................
# [CV 3/5; 1/4] END ...............estimator__C=1;, score=0.000 total time=   8.3s
# [CV 4/5; 1/4] START estimator__C=1..............................................
# [CV 4/5; 1/4] END ...............estimator__C=1;, score=0.000 total time=   8.3s
# [CV 5/5; 1/4] START estimator__C=1..............................................
# [CV 5/5; 1/4] END ...............estimator__C=1;, score=0.000 total time=   8.3s
# [CV 1/5; 2/4] START estimator__C=10.............................................
# [CV 1/5; 2/4] END ..............estimator__C=10;, score=0.077 total time=   9.8s
# [CV 2/5; 2/4] START estimator__C=10.............................................
# [CV 2/5; 2/4] END ..............estimator__C=10;, score=0.903 total time=   9.3s
# [CV 3/5; 2/4] START estimator__C=10.............................................
# [CV 3/5; 2/4] END ..............estimator__C=10;, score=0.058 total time=   9.6s
# [CV 4/5; 2/4] START estimator__C=10.............................................
# [CV 4/5; 2/4] END ..............estimator__C=10;, score=0.355 total time=   9.4s
# [CV 5/5; 2/4] START estimator__C=10.............................................
# [CV 5/5; 2/4] END ..............estimator__C=10;, score=0.123 total time=   9.6s
# [CV 1/5; 3/4] START estimator__C=100............................................
# [CV 1/5; 3/4] END .............estimator__C=100;, score=2.069 total time=   9.7s
# [CV 2/5; 3/4] START estimator__C=100............................................
# [CV 2/5; 3/4] END .............estimator__C=100;, score=1.733 total time=   9.5s
# [CV 3/5; 3/4] START estimator__C=100............................................
# [CV 3/5; 3/4] END .............estimator__C=100;, score=1.942 total time=   9.7s
# [CV 4/5; 3/4] START estimator__C=100............................................
# [CV 4/5; 3/4] END .............estimator__C=100;, score=4.934 total time=   9.7s
# [CV 5/5; 3/4] START estimator__C=100............................................
# [CV 5/5; 3/4] END .............estimator__C=100;, score=1.198 total time=   9.7s
# [CV 1/5; 4/4] START estimator__C=1000...........................................
# [CV 1/5; 4/4] END ............estimator__C=1000;, score=5.208 total time=   9.9s
# [CV 2/5; 4/4] START estimator__C=1000...........................................
# [CV 2/5; 4/4] END ............estimator__C=1000;, score=5.508 total time=   9.5s
# [CV 3/5; 4/4] START estimator__C=1000...........................................
# [CV 3/5; 4/4] END ............estimator__C=1000;, score=2.345 total time=   9.9s
# [CV 4/5; 4/4] START estimator__C=1000...........................................
# [CV 4/5; 4/4] END ............estimator__C=1000;, score=2.288 total time=   9.7s
# [CV 5/5; 4/4] START estimator__C=1000...........................................
# [CV 5/5; 4/4] END ............estimator__C=1000;, score=6.656 total time=   9.8s
# GridSearchCV(cv=5, estimator=OneVsRestClassifier(estimator=LinearSVC()),
#              param_grid={'estimator__C': [1, 10, 100, 1000]},
#              scoring=make_scorer(avg_jacard), verbose=10)

# %%
CV_svc.best_params_
# Out:
# {'estimator__C': 1000}

# %%
best_model = CV_svc.best_estimator_

# %%
y_pred = best_model.predict(X_test)

print_score(y_pred, best_model)
# Out:
# Clf:  OneVsRestClassifier
# Jacard score: 0.6715167548500882
# Hamming loss: 4.588888888888889
# ---

# %% [markdown]
# Confusion matrix

# %%
for i in range(y_train.shape[1]):
    print(multilabel_binarizer.classes_[i])
    print(confusion_matrix(y_test[:,i], y_pred[:,i]))
    print("")
# Out:
# ajax
# [[537   0]
#  [  3   0]]
#
# algorithm
# [[530   0]
#  [ 10   0]]
#
# amazon
# [[534   0]
#  [  6   0]]
#
# android
# [[485   0]
#  [ 55   0]]
#
# angular
# [[536   0]
#  [  4   0]]
#
# apache
# [[537   0]
#  [  3   0]]
#
# api
# [[528   0]
#  [ 12   0]]
#
# array
# [[532   0]
#  [  8   0]]
#
# asp
# [[514   0]
#  [ 26   0]]
#
# authentication
# [[533   0]
#  [  7   0]]
#
# bash
# [[534   0]
#  [  6   0]]
#
# build
# [[536   0]
#  [  4   0]]
#
# c
# [[394   6]
#  [139   1]]
#
# chrome
# [[533   0]
#  [  7   0]]
#
# class
# [[533   0]
#  [  7   0]]
#
# cocoa
# [[527   0]
#  [ 13   0]]
#
# code
# [[534   0]
#  [  6   0]]
#
# command
# [[535   0]
#  [  5   0]]
#
# core
# [[534   0]
#  [  6   0]]
#
# cs
# [[529   0]
#  [ 11   0]]
#
# data
# [[523   0]
#  [ 17   0]]
#
# database
# [[529   0]
#  [ 11   0]]
#
# dataframe
# [[538   0]
#  [  2   0]]
#
# design
# [[531   0]
#  [  9   0]]
#
# django
# [[536   0]
#  [  4   0]]
#
# eclipse
# [[530   0]
#  [ 10   0]]
#
# entity
# [[527   0]
#  [ 13   0]]
#
# event
# [[535   0]
#  [  5   0]]
#
# facebook
# [[535   0]
#  [  5   0]]
#
# file
# [[525   0]
#  [ 15   0]]
#
# framework
# [[527   0]
#  [ 13   0]]
#
# function
# [[531   0]
#  [  9   0]]
#
# git
# [[532   0]
#  [  8   0]]
#
# google
# [[528   0]
#  [ 12   0]]
#
# gradle
# [[536   0]
#  [  4   0]]
#
# hibernate
# [[535   0]
#  [  5   0]]
#
# html
# [[510   0]
#  [ 30   0]]
#
# http
# [[534   0]
#  [  6   0]]
#
# image
# [[526   0]
#  [ 14   0]]
#
# interface
# [[532   0]
#  [  8   0]]
#
# io
# [[473   0]
#  [ 67   0]]
#
# iphone
# [[507   0]
#  [ 33   0]]
#
# j
# [[525   0]
#  [ 15   0]]
#
# java
# [[474   0]
#  [ 66   0]]
#
# javascript
# [[492   0]
#  [ 48   0]]
#
# jpa
# [[533   0]
#  [  7   0]]
#
# jquery
# [[526   0]
#  [ 14   0]]
#
# json
# [[529   0]
#  [ 11   0]]
#
# laravel
# [[538   0]
#  [  2   0]]
#
# layout
# [[  1 532]
#  [  0   7]]
#
# learning
# [[535   0]
#  [  5   0]]
#
# library
# [[537   0]
#  [  3   0]]
#
# line
# [[535   0]
#  [  5   0]]
#
# linux
# [[526   0]
#  [ 14   0]]
#
# macos
# [[  0 535]
#  [  0   5]]
#
# maven
# [[535   0]
#  [  5   0]]
#
# memory
# [[533   0]
#  [  7   0]]
#
# mongodb
# [[535   0]
#  [  5   0]]
#
# multithreading
# [[532   0]
#  [  8   0]]
#
# mvc
# [[524   0]
#  [ 16   0]]
#
# mysql
# [[535   0]
#  [  5   0]]
#
# net
# [[483   0]
#  [ 57   0]]
#
# node
# [[530   0]
#  [ 10   0]]
#
# numpy
# [[531   0]
#  [  9   0]]
#
# objective
# [[504   0]
#  [ 36   0]]
#
# optimization
# [[534   0]
#  [  6   0]]
#
# panda
# [[536   0]
#  [  4   0]]
#
# performance
# [[524   0]
#  [ 16   0]]
#
# php
# [[527   0]
#  [ 13   0]]
#
# postgresql
# [[536   0]
#  [  4   0]]
#
# processing
# [[530   0]
#  [ 10   0]]
#
# python
# [[484   0]
#  [ 56   0]]
#
# r
# [[534   0]
#  [  6   0]]
#
# rail
# [[526   0]
#  [ 14   0]]
#
# reactjs
# [[537   0]
#  [  3   0]]
#
# rest
# [[534   0]
#  [  6   0]]
#
# ruby
# [[522   0]
#  [ 18   0]]
#
# security
# [[527   0]
#  [ 13   0]]
#
# selenium
# [[536   0]
#  [  4   0]]
#
# server
# [[523   0]
#  [ 17   0]]
#
# service
# [[531   0]
#  [  9   0]]
#
# shell
# [[529   0]
#  [ 11   0]]
#
# spark
# [[536   3]
#  [  1   0]]
#
# spring
# [[522   0]
#  [ 18   0]]
#
# sql
# [[520   0]
#  [ 20   0]]
#
# string
# [[530   0]
#  [ 10   0]]
#
# studio
# [[521   0]
#  [ 19   0]]
#
# swift
# [[525   0]
#  [ 15   0]]
#
# testing
# [[536   0]
#  [  4   0]]
#
# touch
# [[527   0]
#  [ 13   0]]
#
# type
# [[531   0]
#  [  9   0]]
#
# ubuntu
# [[535   0]
#  [  5   0]]
#
# video
# [[532   0]
#  [  8   0]]
#
# visual
# [[530   0]
#  [ 10   0]]
#
# web
# [[522   0]
#  [ 18   0]]
#
# window
# [[525   0]
#  [ 15   0]]
#
# wpf
# [[533   0]
#  [  7   0]]
#
# x
# [[531   0]
#  [  9   0]]
#
# xcode
# [[526   0]
#  [ 14   0]]
#
# xml
# [[529   0]
#  [ 11   0]]

# %% [markdown]
# Exctracting feature importance

# %%
def print_top10(feature_names, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("--------------------------------------------")
        print("%s: %s" % (class_label,
              " ".join(feature_names[j] for j in top10)))
        print("--------------------------------------------")

# %%
feature_names = vectorizer_X.get_feature_names()

# %%
print_top10(feature_names, best_model, multilabel_binarizer.classes_)
# Out:
# --------------------------------------------
# ajax: 36 accept 13 -gt -1 22 52 across 05 32
# --------------------------------------------
# --------------------------------------------
# algorithm: 100 09-11 -o 05 9935 14 10 23 13 01
# --------------------------------------------
# --------------------------------------------
# amazon: across 14 50 11 achieve 200 -- 23 22 9935
# --------------------------------------------
# --------------------------------------------
# android: 9935 21 31 35 29 12 -o 36 2019-12-06t00 52
# --------------------------------------------
# --------------------------------------------
# angular: 45 05 26 09-11 25 35 400 account access 32
# --------------------------------------------
# --------------------------------------------
# apache: 400 25 -gt 12 17 accept accord able 05 29
# --------------------------------------------
# --------------------------------------------
# api: action 100 31 14 26 32 00 23 -o 20
# --------------------------------------------
# --------------------------------------------
# array: 11 23 1000 40 action 10 -o account 52 100
# --------------------------------------------
# --------------------------------------------
# asp: 11 account 1000 32 12 21 access achieve 31 05
# --------------------------------------------
# --------------------------------------------
# authentication: 1000 40 50 23 able 10 20 31 access 12
# --------------------------------------------
# --------------------------------------------
# bash: achieve 20 09-11 -o 11 -- 1000 access across 35
# --------------------------------------------
# --------------------------------------------
# build: 45 20 17 11 15 1000 26 action achieve --
# --------------------------------------------
# --------------------------------------------
# c: 25 50 16 22 124 36 accept account 30 able
# --------------------------------------------
# --------------------------------------------
# chrome: 40 26 15 100 --- 21 50 23 -1 across
# --------------------------------------------
# --------------------------------------------
# class: able 16 -- 00 14 29 -1 45 account accord
# --------------------------------------------
# --------------------------------------------
# cocoa: 21 50 11 200 15 1000 able 29 30 --
# --------------------------------------------
# --------------------------------------------
# code: 25 00 13 17 52 access 36 2019-12-06t00 200 30
# --------------------------------------------
# --------------------------------------------
# command: access 31 action 35 200 -gt 05 00 -i 36
# --------------------------------------------
# --------------------------------------------
# core: 52 -gt able --- 11 50 -1 action 25 36
# --------------------------------------------
# --------------------------------------------
# cs: account -1 100 across accept -- 45 26 23 achieve
# --------------------------------------------
# --------------------------------------------
# data: 2019-12-06t00 access 32 15 00 13 21 12 across -gt
# --------------------------------------------
# --------------------------------------------
# database: 400 35 -i 00 200 action 12 access across accept
# --------------------------------------------
# --------------------------------------------
# dataframe: access 52 35 50 account 21 accord action 57342 22
# --------------------------------------------
# --------------------------------------------
# design: 52 11 achieve access 16 -i 21 400 -1 22
# --------------------------------------------
# --------------------------------------------
# django: accept 13 21 52 31 36 able 200 32 accord
# --------------------------------------------
# --------------------------------------------
# eclipse: 200 400 10 13 2019-12-06t00 -i -gt 50 21 36
# --------------------------------------------
# --------------------------------------------
# entity: -1 12 20 124 access 36 9935 17 25 23
# --------------------------------------------
# --------------------------------------------
# event: 50 across 00 40 account 10 22 1000 29 57342
# --------------------------------------------
# --------------------------------------------
# facebook: 22 57342 31 -1 200 45 9935 15 50 30
# --------------------------------------------
# --------------------------------------------
# file: 16 45 -gt 26 14 09-11 25 17 accept 52
# --------------------------------------------
# --------------------------------------------
# framework: 21 35 able 1000 2019-12-06t00 access 09-11 11 17 00
# --------------------------------------------
# --------------------------------------------
# function: --- 45 action 09-11 -gt account 05 52 32 access
# --------------------------------------------
# --------------------------------------------
# git: 57342 accord 16 -gt --- 09-11 400 00 access 52
# --------------------------------------------
# --------------------------------------------
# google: 200 52 -gt 30 124 100 11 21 2019-12-06t00 26
# --------------------------------------------
# --------------------------------------------
# gradle: 9935 31 30 29 accept 32 45 11 52 access
# --------------------------------------------
# --------------------------------------------
# hibernate: 13 2019-12-06t00 accord 1000 124 20 access 26 31 across
# --------------------------------------------
# --------------------------------------------
# html: 9935 account --- 22 50 able 14 23 36 achieve
# --------------------------------------------
# --------------------------------------------
# http: 20 2019-12-06t00 --- 26 50 -1 45 able account 40
# --------------------------------------------
# --------------------------------------------
# image: 45 9935 2019-12-06t00 52 21 200 1000 able 57342 achieve
# --------------------------------------------
# --------------------------------------------
# interface: 01 35 30 26 57342 45 200 29 access 20
# --------------------------------------------
# --------------------------------------------
# io: 05 01 accept 29 -o 09-11 2019-12-06t00 achieve 23 35
# --------------------------------------------
# --------------------------------------------
# iphone: 1000 400 36 account 57342 2019-12-06t00 50 17 25 able
# --------------------------------------------
# --------------------------------------------
# j: 14 9935 26 10 124 17 05 1000 52 40
# --------------------------------------------
# --------------------------------------------
# java: 40 -i 12 achieve 26 2019-12-06t00 -1 access 21 100
# --------------------------------------------
# --------------------------------------------
# javascript: 40 2019-12-06t00 22 36 account 200 --- 50 57342 action
# --------------------------------------------
# --------------------------------------------
# jpa: 23 124 21 32 10 52 15 access achieve across
# --------------------------------------------
# --------------------------------------------
# jquery: 13 26 29 12 00 32 57342 across accord ---
# --------------------------------------------
# --------------------------------------------
# json: 200 40 action --- 05 able 29 100 1000 13
# --------------------------------------------
# --------------------------------------------
# laravel: 32 across 124 20 57342 100 12 2019-12-06t00 31 accept
# --------------------------------------------
# --------------------------------------------
# layout: 21 400 access accept -gt --- 36 05 13 --
# --------------------------------------------
# --------------------------------------------
# learning: 52 access -gt 40 16 50 23 able 36 200
# --------------------------------------------
# --------------------------------------------
# library: -i 09-11 29 1000 25 -- 26 200 57342 21
# --------------------------------------------
# --------------------------------------------
# line: action 10 100 -1 --- 22 account 36 access 00
# --------------------------------------------
# --------------------------------------------
# linux: 124 01 15 31 35 400 9935 00 across accord
# --------------------------------------------
# --------------------------------------------
# macos: 50 15 29 100 21 26 2019-12-06t00 52 12 --
# --------------------------------------------
# --------------------------------------------
# maven: 124 57342 100 2019-12-06t00 accept 13 50 10 access ---
# --------------------------------------------
# --------------------------------------------
# memory: able 23 10 09-11 15 22 11 16 -- 9935
# --------------------------------------------
# --------------------------------------------
# mongodb: 124 15 31 17 26 52 -1 40 -gt 16
# --------------------------------------------
# --------------------------------------------
# multithreading: 22 31 -gt 2019-12-06t00 action 14 -i 36 1000 --
# --------------------------------------------
# --------------------------------------------
# mvc: achieve accord -i 22 21 57342 -gt action 12 9935
# --------------------------------------------
# --------------------------------------------
# mysql: 32 action 29 across 09-11 57342 26 50 40 31
# --------------------------------------------
# --------------------------------------------
# net: 35 21 14 -- -o 01 31 accept action 12
# --------------------------------------------
# --------------------------------------------
# node: 36 25 -o 9935 05 35 action 23 40 able
# --------------------------------------------
# --------------------------------------------
# numpy: 2019-12-06t00 52 400 100 action 45 account achieve 1000 9935
# --------------------------------------------
# --------------------------------------------
# objective: 57342 2019-12-06t00 -gt 100 00 25 accept -o 30 10
# --------------------------------------------
# --------------------------------------------
# optimization: 40 17 30 -1 05 able 25 31 9935 ---
# --------------------------------------------
# --------------------------------------------
# panda: 01 -- 9935 40 across 124 -i 32 action 52
# --------------------------------------------
# --------------------------------------------
# performance: 40 124 30 26 400 10 able 20 09-11 17
# --------------------------------------------
# --------------------------------------------
# php: -- action able 22 12 20 30 9935 across 32
# --------------------------------------------
# --------------------------------------------
# postgresql: -1 36 9935 14 11 12 35 account 30 20
# --------------------------------------------
# --------------------------------------------
# processing: 10 31 -gt 100 32 01 1000 57342 50 --
# --------------------------------------------
# --------------------------------------------
# python: 32 22 100 1000 00 15 400 11 200 14
# --------------------------------------------
# --------------------------------------------
# r: 14 00 17 35 400 -gt 23 account 22 31
# --------------------------------------------
# --------------------------------------------
# rail: 124 9935 22 15 00 12 across 20 account 30
# --------------------------------------------
# --------------------------------------------
# reactjs: -1 11 13 26 1000 account 25 35 31 access
# --------------------------------------------
# --------------------------------------------
# rest: achieve 124 22 200 29 30 access 32 13 31
# --------------------------------------------
# --------------------------------------------
# ruby: 05 100 account across --- 32 14 -gt 22 9935
# --------------------------------------------
# --------------------------------------------
# security: able 400 16 01 36 100 --- 45 52 -o
# --------------------------------------------
# --------------------------------------------
# selenium: 400 50 40 36 100 2019-12-06t00 45 accord 23 --
# --------------------------------------------
# --------------------------------------------
# server: -- accord achieve 01 13 2019-12-06t00 26 29 access 14
# --------------------------------------------
# --------------------------------------------
# service: account 29 200 across 45 05 17 9935 50 100
# --------------------------------------------
# --------------------------------------------
# shell: action 57342 14 11 29 32 09-11 25 35 --
# --------------------------------------------
# --------------------------------------------
# spark: 45 17 accept 14 --- 9935 16 accord 26 29
# --------------------------------------------
# --------------------------------------------
# spring: 32 31 16 13 accord 100 14 achieve 17 access
# --------------------------------------------
# --------------------------------------------
# sql: 25 able 13 20 14 access 12 35 01 17
# --------------------------------------------
# --------------------------------------------
# string: 124 11 200 13 14 access 25 across 22 15
# --------------------------------------------
# --------------------------------------------
# studio: -1 16 12 access 20 13 -i 22 -- 52
# --------------------------------------------
# --------------------------------------------
# swift: able 100 -i 20 50 -- 40 57342 achieve 23
# --------------------------------------------
# --------------------------------------------
# testing: 05 accord 52 action 11 01 accept 16 40 50
# --------------------------------------------
# --------------------------------------------
# touch: across action 31 29 09-11 11 30 2019-12-06t00 able --
# --------------------------------------------
# --------------------------------------------
# type: 40 -gt 22 accept 12 100 400 26 accord action
# --------------------------------------------
# --------------------------------------------
# ubuntu: 00 31 14 12 30 across accord 200 achieve 45
# --------------------------------------------
# --------------------------------------------
# video: 40 100 45 accord 22 35 50 action access account
# --------------------------------------------
# --------------------------------------------
# visual: 16 12 1000 20 400 52 30 22 -- 31
# --------------------------------------------
# --------------------------------------------
# web: 32 30 21 accept achieve 26 account -i -o access
# --------------------------------------------
# --------------------------------------------
# window: account 9935 32 -gt --- 13 25 00 52 21
# --------------------------------------------
# --------------------------------------------
# wpf: 21 57342 31 26 12 1000 01 00 200 --
# --------------------------------------------
# --------------------------------------------
# x: 16 accept 14 32 -- 01 29 able across 1000
# --------------------------------------------
# --------------------------------------------
# xcode: 15 05 accord achieve 45 2019-12-06t00 action 25 09-11 10
# --------------------------------------------
# --------------------------------------------
# xml: 29 01 30 22 11 achieve able access 100 400
# --------------------------------------------

# %% [markdown]
# # USE - Universal Sentence Encoder

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2020/08/top-4-sentence-embedding-techniques-using-python/

# %% [markdown]
# Universal Sentence Encoder
# One of the most well-performing sentence embedding techniques right now is the Universal Sentence Encoder. And it should come as no surprise from anybody that it has been proposed by Google. The key feature here is that we can use it for Multi-task learning.
#
# This means that the sentence embeddings we generate can be used for multiple tasks like sentiment analysis, text classification, sentence similarity, etc, and the results of these asks are then fed back to the model to get even better sentence vectors that before.
#
# The most interesting part is that this encoder is based on two encoder models and we can use either of the two:
#
# Transformer
# Deep Averaging Network(DAN)
# Both of these models are capable of taking a word or a sentence as input and generating embeddings for the same. The following is the basic flow:
#
# Tokenize the sentences after converting them to lowercase
# Depending on the type of encoder, the sentence gets converted to a 512-dimensional vector
# If we use the transformer, it is similar to the encoder module of the transformer architecture and uses the self-attention mechanism.
# The DAN option computes the unigram and bigram embeddings first and then averages them to get a single embedding. This is then passed to a deep neural network to get a final sentence embedding of 512 dimensions.
# These sentence embeddings are then used for various unsupervised and supervised tasks like Skipthoughts, NLI, etc. The trained model is then again reused to generate a new 512 dimension sentence embedding.

# %%
import os 
import tensorflow as tf
# import tensorflow_hub as hub
import tensorflow.keras
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import metrics as kmetrics
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

# Bert
import transformers
from transformers import *

os.environ["TF_KERAS"]='1'

# %%
print(tf.__version__)
print(tensorflow.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())
# Out:
# 2.10.0
# 2.10.0
# Num GPUs Available:  0
# True

# %%
pip uninstall h5py

# %%
pip install h5py

# %%
import tensorflow_hub as hub
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-227-77397eaab1c6> in <module>
#       1 import tensorflow_hub as hub
# ----> 2 embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
#
# C:\Python\envs\TensorFlow\lib\site-packages\tensorflow_hub\module_v2.py in load(handle, tags, options)
#     104         module_path, tags=tags, options=options)
#     105   else:
# --> 106     obj = tf.compat.v1.saved_model.load_v2(module_path, tags=tags)
#     107   obj._is_hub_module_v1 = is_hub_module_v1  # pylint: disable=protected-access
#     108   return obj
#
# C:\Python\envs\TensorFlow\lib\site-packages\tensorflow\python\saved_model\load.py in load(export_dir, tags, options)
#     798   if isinstance(export_dir, os.PathLike):
#     799     export_dir = os.fspath(export_dir)
# --> 800   result = load_partial(export_dir, None, tags, options)["root"]
#     801   return result
#     802
#
# C:\Python\envs\TensorFlow\lib\site-packages\tensorflow\python\saved_model\load.py in load_partial(export_dir, filters, tags, options)
#     903     tags = nest.flatten(tags)
#     904   saved_model_proto, debug_info = (
# --> 905       loader_impl.parse_saved_model_with_debug_info(export_dir))
#     906
#     907   if (len(saved_model_proto.meta_graphs) == 1 and
#
# C:\Python\envs\TensorFlow\lib\site-packages\tensorflow\python\saved_model\loader_impl.py in parse_saved_model_with_debug_info(export_dir)
#      55     parsed. Missing graph debug info file is fine.
#      56   """
# ---> 57   saved_model = parse_saved_model(export_dir)
#      58
#      59   debug_info_path = file_io.join(
#
# C:\Python\envs\TensorFlow\lib\site-packages\tensorflow\python\saved_model\loader_impl.py in parse_saved_model(export_dir)
#     113       raise IOError(f"Cannot parse file {path_to_pbtxt}: {str(e)}.")
#     114   else:
# --> 115     raise IOError(
#     116         f"SavedModel file does not exist at: {export_dir}{os.path.sep}"
#     117         f"{{{constants.SAVED_MODEL_FILENAME_PBTXT}|"
#
# OSError: SavedModel file does not exist at: C:\Users\ray63\AppData\Local\Temp\tfhub_modules\063d866c06683311b44b4992fd46003be952409c\{saved_model.pbtxt|saved_model.pb}

# %%
def feature_USE_fct(sentences, b_size) :
    batch_size = b_size
    time1 = time.time()

    for step in range(len(sentences)//batch_size) :
        idx = step*batch_size
        feat = embed(sentences[idx:idx+batch_size])

        if step ==0 :
            features = feat
        else :
            features = np.concatenate((features,feat))

    time2 = np.round(time.time() - time1,0)
    return features

# %%
batch_size = 10
sentences = df1['full_review'].to_list()

# %%
features_USE = feature_USE_fct(sentences, batch_size)

# %%
features_USE

# %%
df1.shape

# %%
df1

# %%
#df1 = df1.sample(n = 2710,replace=True)

# %%
y = df1['Tags']

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %%
y_bin.shape

# %% [markdown]
# # USE PCA

# %%
clf = TruncatedSVD(500)
Xpca = clf.fit_transform(features_USE)

# %%
clf.explained_variance_ratio_

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, 501), clf.explained_variance_ratio_.cumsum(),marker = "o", linestyle = "--")
plt.title("Explained Variance by Componants")
plt.xlabel("Nomber of componants")
plt.ylabel("Explained Variance")

# %%
clf = TruncatedSVD(100)
Xpca_features_USE = clf.fit_transform(features_USE)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Xpca_features_USE,y_bin, test_size = 0.2, random_state = 0)

# %%
def avg_jacard(y_true,y_pred):
    jacard = np.minimum(y_true,y_pred).sum(axis=1) / np.maximum(y_true,y_pred).sum(axis=1)    
    return jacard.mean()*100
    
def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    print("Jacard score: {}".format(avg_jacard(y_test, y_pred)))
    print("Hamming loss: {}".format(hamming_loss(y_pred, y_test)*100))
    print("---")

# %%
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.svm import LinearSVC
dummy = DummyClassifier()
sgd = SGDClassifier()
lr = LogisticRegression()
svc = LinearSVC()
perceptron = Perceptron()
pac = PassiveAggressiveClassifier()

for classifier in [dummy, sgd, lr, svc, perceptron, pac]:
    clf = OneVsRestClassifier(classifier)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print_score(y_pred, classifier)

# %%
SGDClassifier

# %%
sgd = SGDClassifier()
clf = OneVsRestClassifier(sgd)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, sgd)

# %%
OneVsRestClassifier

# %%
lr = LogisticRegression()

clf = OneVsRestClassifier(lr)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, lr)

# %% [markdown]
# MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier()
mlpc.fit(X_train, y_train)

y_pred = mlpc.predict(X_test)

print_score(y_pred, mlpc)

# %%
#Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

print_score(y_pred, rfc)

# %% [markdown]
# GridSearch CV on the best classifier

# %%
param_grid = {'estimator__C':[1,10,100,1000]
              }

# %%
svc = OneVsRestClassifier(LinearSVC())
CV_svc = model_selection.GridSearchCV(estimator=svc, param_grid=param_grid, cv= 5, verbose=10, scoring=make_scorer(avg_jacard,greater_is_better=True))
CV_svc.fit(X_train, y_train)

# %%
CV_svc.best_params_

# %%
best_model = CV_svc.best_estimator_

# %%
y_pred = best_model.predict(X_test)

print_score(y_pred, best_model)

# %% [markdown]
# Confusion matrix

# %%
for i in range(y_train.shape[1]):
    print(multilabel_binarizer.classes_[i])
    print(confusion_matrix(y_test[:,i], y_pred[:,i]))
    print("")

# %% [markdown]
# Exctracting feature importance

# %%
def print_top10(feature_names, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("--------------------------------------------")
        print("%s: %s" % (class_label,
              " ".join(feature_names[j] for j in top10)))
        print("--------------------------------------------")

# %%
feature_names = vectorizer_X.get_feature_names()

# %%
print_top10(feature_names, best_model, multilabel_binarizer.classes_)

# %% [markdown]
# # What is the Jaccard Index?
#
# The Jaccard similarity index (sometimes called the Jaccard similarity coefficient) compares members for two sets to see which members are shared and which are distinct. It’s a measure of similarity for the two sets of data, with a range from 0% to 100%. The higher the percentage, the more similar the two populations. Although it’s easy to interpret, it is extremely sensitive to small samples sizes and may give erroneous results, especially with very small samples or data sets with missing observations.
#
# How to Calculate the Jaccard Index
# The formula to find the Index is:
#
# Jaccard Index = (the number in both sets) / (the number in either set) * 100
#
# The same formula in notation is:
# J(X,Y) = |X∩Y| / |X∪Y|

# %% [markdown]
# # Hamming loss

# %% [markdown]
# Hamming loss is the fraction of wrong labels to the total number of labels. In multi-class classification, hamming loss is calculated as the hamming distance between y_true and y_pred . In multi-label classification, hamming loss penalizes only the individual labels.

# %%
df1

# %%
tags_Count =df1['clean_tags'].value_counts()
tags_Count

# %%
Tags_Count =df1['clean_tags'].value_counts()[:30]
Tags_Count[:30]

# %%
Tags_Count.plot(kind='barh',label='tags Count',figsize=(8,9),colormap='plasma')

# %%
Tags_Count.plot(kind='barh',label='Tags Count Top 30',figsize=(8,10),colormap='cool')

# %%
#pip install networkx

# %%
#pip install --upgrade networkx

# %%
import networkx as nx
import seaborn as sns
# %matplotlib inline

# %%
# https://www.kaggle.com/code/fanbyprinciple/text-exploration-of-shakespearean-plays


wrdcld = pd.Series(df1['full_review'].tolist()).astype(str)

# %%
df1.groupby('clean_tags').count()

# %%
play_data = df1.groupby('clean_tags').count().sort_values(by='full_review', ascending=False)['full_review']
play_data

# %%
play_data = play_data.to_frame()
play_data

# %%
play_data.index = np.arange(0, len(play_data))

# %%
full_text = "\n".join(df1.full_review)
print(len(full_text))

# %%
import collections
import re

# %%
counter = 1
for i in df1.full_review:
    print(i)
    print(re.sub('[^A-Za-z]+', ' ', i).strip().lower())
    if counter>5:
        break
    counter+=1

# %%
# ignoring punctuation and captalisation

def ignore_punctuation(text_array):
    return [re.sub('[^A-Za-z]+', ' ', line ).strip().lower() for line in text_array]

lines = ignore_punctuation(df1.full_review)

# %%
print(lines[0])
print(lines[1])

# %%
def tokenize(lines, token='word'):
    if token=='word':
        return [line.split(' ') for line in lines]
    
    elif token=='char':
        return [list(line) for line in lines]
    
    else :
        print('ERROR: unknown type: ' + token)

tokens = tokenize(lines)

# %%
for i in range(5):
    print(tokens[i])

# %%
def count_corpus(tokens):
    token_dict = {}
    
    for token in tokens:
        for i in token:
            if i not in token_dict.keys():
                token_dict[i] = 1
            else:
                token_dict[i] += 1
    
    #print(token_dict)
    
    if len(tokens)==0 or isinstance(tokens[0], list):
        print("tokens needs flattening")
        tokens = [token for line in tokens for token in line ]
    new_dict = collections.Counter(tokens)
    
    #print(new_dict)
    return new_dict

# %%
count_corpus(tokens[:5])

# %%
class Vocab:
    def __init__(self, tokens=None, min_freq=0, reserved_tokens=None):
        if tokens==None:
            tokens=[]
        if reserved_tokens==None:
            reserved_tokens=[]
        
        counter = count_corpus(tokens)
        
        self._token_freqs = sorted(counter.items(), key=lambda x: x[1], reverse=1)
        
        self.idx_to_token = ['<unk>'] + reserved_tokens
        
        self.token_to_idx = {token: idx for idx, token in enumerate(self.idx_to_token)}
        
        for token, freq in self._token_freqs:
            if freq < min_freq:
                break
            if token not in self.token_to_idx:
                self.idx_to_token.append(token)
                self.token_to_idx[token] = len(self.idx_to_token) -1 
        
    
    def __len__(self):
        return len(self.idx_to_token)
    
    def __getitem__(self, tokens):
        if not isinstance(tokens, (list, tuple)):
            return self.token_to_idx.get(tokens, self.unk)
        return [self.__getitem(token) for token in tokens]
    
    def to_tokens(self, indices):
        if not isinstance(indices, (list, tuple)):
            return self.idx_to_token[indices]
        return [self.idx_to_token[index] for index in indices]
    
    def unk(self):
        return 0
    
    def token_freqs(self):
        return self.token_freqs

# %%
vocab = Vocab(tokens)

# %%
print(list(vocab.token_to_idx.items())[:50])

# %%
corpus = [vocab[token] for line in tokens for token in line]

# %%
print("Total length of corpus: ", len(corpus))
print("Vocab size of text: ", len(vocab))
